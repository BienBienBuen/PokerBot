# %%
import torch

if torch.cuda.is_available():
    print("CUDA is available. PyTorch can use the GPU.")
    print(f"Number of GPUs: {torch.cuda.device_count()}")
    print(f"Current GPU: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is not available. PyTorch will use the CPU.")
# Out:
# CUDA is available. PyTorch can use the GPU.
# Number of GPUs: 1
# Current GPU: NVIDIA GeForce RTX 4050 Laptop GPU

# %%
import os
import re

# Define the path to the root folder
root_folder_path = r'phh-dataset'

# Counter for deleted files
deleted_count = 0
total_count = 0
folders_processed = 0

print("Starting recursive processing of all .phh files in phh-dataset...")
print("-" * 60)

# Walk through all directories and subdirectories
for root, dirs, files in os.walk(root_folder_path):
    # Skip if no .phh files in current directory
    phh_files = [f for f in files if f.endswith('.phh')]
    if not phh_files:
        continue
    
    folders_processed += 1
    print(f"\nProcessing folder: {root}")
    print(f"Found {len(phh_files)} .phh files")
    
    # Process each .phh file in current directory
    for filename in phh_files:
        total_count += 1
        file_path = os.path.join(root, filename)
        
        try:
            # Read the first few lines to check for variant
            with open(file_path, 'r', encoding='utf-8') as file:
                first_line = file.readline().strip()
                
            # Check if the first line contains variant = 'NT'
            if first_line.startswith("variant = 'NT'"):
                print(f"  ✓ Keeping: {filename} (variant = 'NT')")
            else:
                # Delete the file if it doesn't have variant = 'NT'
                if '=' in first_line:
                    variant_value = first_line.split('=')[1].strip().strip("'")
                else:
                    variant_value = 'unknown'
                
                os.remove(file_path)
                deleted_count += 1
                print(f"  ✗ Deleted: {filename} (variant = '{variant_value}')")
                
        except Exception as e:
            print(f"  ! Error processing {filename}: {e}")

print("\n" + "=" * 60)
print("PROCESSING COMPLETE!")
print(f"Folders processed: {folders_processed}")
print(f"Total files processed: {total_count}")
print(f"Files deleted: {deleted_count}")
print(f"Files kept: {total_count - deleted_count}")
if total_count > 0:
    print(f"Deletion rate: {deleted_count/total_count*100:.1f}%")
# Out:
# Starting recursive processing of all .phh files in phh-dataset...
# ------------------------------------------------------------
#
# Processing folder: phh-dataset\data\pluribus\100
# Found 71 .phh files
#   ✓ Keeping: 0.phh (variant = 'NT')
#   ✓ Keeping: 1.phh (variant = 'NT')
#   ✓ Keeping: 10.phh (variant = 'NT')
#   ✓ Keeping: 11.phh (variant = 'NT')
#   ✓ Keeping: 12.phh (variant = 'NT')
#   ✓ Keeping: 13.phh (variant = 'NT')
#   ✓ Keeping: 14.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\100
# Found 71 .phh files
#   ✓ Keeping: 0.phh (variant = 'NT')
#   ✓ Keeping: 1.phh (variant = 'NT')
#   ✓ Keeping: 10.phh (variant = 'NT')
#   ✓ Keeping: 11.phh (variant = 'NT')
#   ✓ Keeping: 12.phh (variant = 'NT')
#   ✓ Keeping: 13.phh (variant = 'NT')
#   ✓ Keeping: 14.phh (variant = 'NT')
#   ✓ Keeping: 15.phh (variant = 'NT')
#   ✓ Keeping: 16.phh (variant = 'NT')
#   ✓ Keeping: 17.phh (variant = 'NT')
#   ✓ Keeping: 18.phh (variant = 'NT')
#   ✓ Keeping: 19.phh (variant = 'NT')
#   ✓ Keeping: 2.phh (variant = 'NT')
#   ✓ Keeping: 20.phh (variant = 'NT')
#   ✓ Keeping: 21.phh (variant = 'NT')
#   ✓ Keeping: 22.phh (variant = 'NT')
#   ✓ Keeping: 23.phh (variant = 'NT')
#   ✓ Keeping: 24.phh (variant = 'NT')
#   ✓ Keeping: 25.phh (variant = 'NT')
#   ✓ Keeping: 15.phh (variant = 'NT')
#   ✓ Keeping: 16.phh (variant = 'NT')
#   ✓ Keeping: 17.phh (variant = 'NT')
#   ✓ Keeping: 18.phh (variant = 'NT')
#   ✓ Keeping: 19.phh (variant = 'NT')
#   ✓ Keeping: 2.phh (variant = 'NT')
#   ✓ Keeping: 20.phh (variant = 'NT')
#   ✓ Keeping: 21.phh (variant = 'NT')
#   ✓ Keeping: 22.phh (variant = 'NT')
#   ✓ Keeping: 23.phh (variant = 'NT')
#   ✓ Keeping: 24.phh (variant = 'NT')
#   ✓ Keeping: 25.phh (variant = 'NT')
#   ✓ Keeping: 26.phh (variant = 'NT')
#   ✓ Keeping: 27.phh (variant = 'NT')
#   ✓ Keeping: 28.phh (variant = 'NT')
#   ✓ Keeping: 29.phh (variant = 'NT')
#   ✓ Keeping: 3.phh (variant = 'NT')
#   ✓ Keeping: 30.phh (variant = 'NT')
#   ✓ Keeping: 31.phh (variant = 'NT')
#   ✓ Keeping: 32.phh (variant = 'NT')
#   ✓ Keeping: 33.phh (variant = 'NT')
#   ✓ Keeping: 34.phh (variant = 'NT')
#   ✓ Keeping: 35.phh (variant = 'NT')
#   ✓ Keeping: 36.phh (variant = 'NT')
#   ✓ Keeping: 37.phh (variant = 'NT')
#   ✓ Keeping: 26.phh (variant = 'NT')
#   ✓ Keeping: 27.phh (variant = 'NT')
#   ✓ Keeping: 28.phh (variant = 'NT')
#   ✓ Keeping: 29.phh (variant = 'NT')
#   ✓ Keeping: 3.phh (variant = 'NT')
#   ✓ Keeping: 30.phh (variant = 'NT')
#   ✓ Keeping: 31.phh (variant = 'NT')
#   ✓ Keeping: 32.phh (variant = 'NT')
#   ✓ Keeping: 33.phh (variant = 'NT')
#   ✓ Keeping: 34.phh (variant = 'NT')
#   ✓ Keeping: 35.phh (variant = 'NT')
#   ✓ Keeping: 36.phh (variant = 'NT')
#   ✓ Keeping: 37.phh (variant = 'NT')
#   ✓ Keeping: 38.phh (variant = 'NT')
#   ✓ Keeping: 39.phh (variant = 'NT')
#   ✓ Keeping: 4.phh (variant = 'NT')
#   ✓ Keeping: 40.phh (variant = 'NT')
#   ✓ Keeping: 41.phh (variant = 'NT')
#   ✓ Keeping: 42.phh (variant = 'NT')
#   ✓ Keeping: 43.phh (variant = 'NT')
#   ✓ Keeping: 44.phh (variant = 'NT')
#   ✓ Keeping: 45.phh (variant = 'NT')
#   ✓ Keeping: 46.phh (variant = 'NT')
#   ✓ Keeping: 47.phh (variant = 'NT')
#   ✓ Keeping: 38.phh (variant = 'NT')
#   ✓ Keeping: 39.phh (variant = 'NT')
#   ✓ Keeping: 4.phh (variant = 'NT')
#   ✓ Keeping: 40.phh (variant = 'NT')
#   ✓ Keeping: 41.phh (variant = 'NT')
#   ✓ Keeping: 42.phh (variant = 'NT')
#   ✓ Keeping: 43.phh (variant = 'NT')
#   ✓ Keeping: 44.phh (variant = 'NT')
#   ✓ Keeping: 45.phh (variant = 'NT')
#   ✓ Keeping: 46.phh (variant = 'NT')
#   ✓ Keeping: 47.phh (variant = 'NT')
#   ✓ Keeping: 48.phh (variant = 'NT')
#   ✓ Keeping: 49.phh (variant = 'NT')
#   ✓ Keeping: 5.phh (variant = 'NT')
#   ✓ Keeping: 50.phh (variant = 'NT')
#   ✓ Keeping: 51.phh (variant = 'NT')
#   ✓ Keeping: 52.phh (variant = 'NT')
#   ✓ Keeping: 53.phh (variant = 'NT')
#   ✓ Keeping: 54.phh (variant = 'NT')
#   ✓ Keeping: 55.phh (variant = 'NT')
#   ✓ Keeping: 56.phh (variant = 'NT')
#   ✓ Keeping: 57.phh (variant = 'NT')
#   ✓ Keeping: 58.phh (variant = 'NT')
#   ✓ Keeping: 59.phh (variant = 'NT')
#   ✓ Keeping: 48.phh (variant = 'NT')
#   ✓ Keeping: 49.phh (variant = 'NT')
#   ✓ Keeping: 5.phh (variant = 'NT')
#   ✓ Keeping: 50.phh (variant = 'NT')
#   ✓ Keeping: 51.phh (variant = 'NT')
#   ✓ Keeping: 52.phh (variant = 'NT')
#   ✓ Keeping: 53.phh (variant = 'NT')
#   ✓ Keeping: 54.phh (variant = 'NT')
#   ✓ Keeping: 55.phh (variant = 'NT')
#   ✓ Keeping: 56.phh (variant = 'NT')
#   ✓ Keeping: 57.phh (variant = 'NT')
#   ✓ Keeping: 58.phh (variant = 'NT')
#   ✓ Keeping: 59.phh (variant = 'NT')
#   ✓ Keeping: 6.phh (variant = 'NT')
#   ✓ Keeping: 60.phh (variant = 'NT')
#   ✓ Keeping: 61.phh (variant = 'NT')
#   ✓ Keeping: 62.phh (variant = 'NT')
#   ✓ Keeping: 63.phh (variant = 'NT')
#   ✓ Keeping: 64.phh (variant = 'NT')
#   ✓ Keeping: 65.phh (variant = 'NT')
#   ✓ Keeping: 66.phh (variant = 'NT')
#   ✓ Keeping: 67.phh (variant = 'NT')
#   ✓ Keeping: 6.phh (variant = 'NT')
#   ✓ Keeping: 60.phh (variant = 'NT')
#   ✓ Keeping: 61.phh (variant = 'NT')
#   ✓ Keeping: 62.phh (variant = 'NT')
#   ✓ Keeping: 63.phh (variant = 'NT')
#   ✓ Keeping: 64.phh (variant = 'NT')
#   ✓ Keeping: 65.phh (variant = 'NT')
#   ✓ Keeping: 66.phh (variant = 'NT')
#   ✓ Keeping: 67.phh (variant = 'NT')
#   ✓ Keeping: 68.phh (variant = 'NT')
#   ✓ Keeping: 69.phh (variant = 'NT')
#   ✓ Keeping: 7.phh (variant = 'NT')
#   ✓ Keeping: 70.phh (variant = 'NT')
#   ✓ Keeping: 8.phh (variant = 'NT')
#   ✓ Keeping: 9.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\100b
# Found 113 .phh files
#   ✓ Keeping: 100.phh (variant = 'NT')
#   ✓ Keeping: 101.phh (variant = 'NT')
#   ✓ Keeping: 102.phh (variant = 'NT')
#   ✓ Keeping: 103.phh (variant = 'NT')
#   ✓ Keeping: 68.phh (variant = 'NT')
#   ✓ Keeping: 69.phh (variant = 'NT')
#   ✓ Keeping: 7.phh (variant = 'NT')
#   ✓ Keeping: 70.phh (variant = 'NT')
#   ✓ Keeping: 8.phh (variant = 'NT')
#   ✓ Keeping: 9.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\100b
# Found 113 .phh files
#   ✓ Keeping: 100.phh (variant = 'NT')
#   ✓ Keeping: 101.phh (variant = 'NT')
#   ✓ Keeping: 102.phh (variant = 'NT')
#   ✓ Keeping: 103.phh (variant = 'NT')
#   ✓ Keeping: 104.phh (variant = 'NT')
#   ✓ Keeping: 105.phh (variant = 'NT')
#   ✓ Keeping: 106.phh (variant = 'NT')
#   ✓ Keeping: 107.phh (variant = 'NT')
#   ✓ Keeping: 108.phh (variant = 'NT')
#   ✓ Keeping: 109.phh (variant = 'NT')
#   ✓ Keeping: 110.phh (variant = 'NT')
#   ✓ Keeping: 111.phh (variant = 'NT')
#   ✓ Keeping: 104.phh (variant = 'NT')
#   ✓ Keeping: 105.phh (variant = 'NT')
#   ✓ Keeping: 106.phh (variant = 'NT')
#   ✓ Keeping: 107.phh (variant = 'NT')
#   ✓ Keeping: 108.phh (variant = 'NT')
#   ✓ Keeping: 109.phh (variant = 'NT')
#   ✓ Keeping: 110.phh (variant = 'NT')
#   ✓ Keeping: 111.phh (variant = 'NT')
#   ✓ Keeping: 112.phh (variant = 'NT')
#   ✓ Keeping: 113.phh (variant = 'NT')
#   ✓ Keeping: 114.phh (variant = 'NT')
#   ✓ Keeping: 115.phh (variant = 'NT')
#   ✓ Keeping: 116.phh (variant = 'NT')
#   ✓ Keeping: 117.phh (variant = 'NT')
#   ✓ Keeping: 118.phh (variant = 'NT')
#   ✓ Keeping: 119.phh (variant = 'NT')
#   ✓ Keeping: 120.phh (variant = 'NT')
#   ✓ Keeping: 112.phh (variant = 'NT')
#   ✓ Keeping: 113.phh (variant = 'NT')
#   ✓ Keeping: 114.phh (variant = 'NT')
#   ✓ Keeping: 115.phh (variant = 'NT')
#   ✓ Keeping: 116.phh (variant = 'NT')
#   ✓ Keeping: 117.phh (variant = 'NT')
#   ✓ Keeping: 118.phh (variant = 'NT')
#   ✓ Keeping: 119.phh (variant = 'NT')
#   ✓ Keeping: 120.phh (variant = 'NT')
#   ✓ Keeping: 121.phh (variant = 'NT')
#   ✓ Keeping: 122.phh (variant = 'NT')
#   ✓ Keeping: 123.phh (variant = 'NT')
#   ✓ Keeping: 124.phh (variant = 'NT')
#   ✓ Keeping: 125.phh (variant = 'NT')
#   ✓ Keeping: 126.phh (variant = 'NT')
#   ✓ Keeping: 121.phh (variant = 'NT')
#   ✓ Keeping: 122.phh (variant = 'NT')
#   ✓ Keeping: 123.phh (variant = 'NT')
#   ✓ Keeping: 124.phh (variant = 'NT')
#   ✓ Keeping: 125.phh (variant = 'NT')
#   ✓ Keeping: 126.phh (variant = 'NT')
#   ✓ Keeping: 127.phh (variant = 'NT')
#   ✓ Keeping: 128.phh (variant = 'NT')
#   ✓ Keeping: 129.phh (variant = 'NT')
#   ✓ Keeping: 130.phh (variant = 'NT')
#   ✓ Keeping: 131.phh (variant = 'NT')
#   ✓ Keeping: 132.phh (variant = 'NT')
#   ✓ Keeping: 133.phh (variant = 'NT')
#   ✓ Keeping: 134.phh (variant = 'NT')
#   ✓ Keeping: 127.phh (variant = 'NT')
#   ✓ Keeping: 128.phh (variant = 'NT')
#   ✓ Keeping: 129.phh (variant = 'NT')
#   ✓ Keeping: 130.phh (variant = 'NT')
#   ✓ Keeping: 131.phh (variant = 'NT')
#   ✓ Keeping: 132.phh (variant = 'NT')
#   ✓ Keeping: 133.phh (variant = 'NT')
#   ✓ Keeping: 134.phh (variant = 'NT')
#   ✓ Keeping: 135.phh (variant = 'NT')
#   ✓ Keeping: 136.phh (variant = 'NT')
#   ✓ Keeping: 137.phh (variant = 'NT')
#   ✓ Keeping: 138.phh (variant = 'NT')
#   ✓ Keeping: 139.phh (variant = 'NT')
#   ✓ Keeping: 140.phh (variant = 'NT')
#   ✓ Keeping: 141.phh (variant = 'NT')
#   ✓ Keeping: 142.phh (variant = 'NT')
#   ✓ Keeping: 143.phh (variant = 'NT')
#   ✓ Keeping: 144.phh (variant = 'NT')
#   ✓ Keeping: 145.phh (variant = 'NT')
#   ✓ Keeping: 135.phh (variant = 'NT')
#   ✓ Keeping: 136.phh (variant = 'NT')
#   ✓ Keeping: 137.phh (variant = 'NT')
#   ✓ Keeping: 138.phh (variant = 'NT')
#   ✓ Keeping: 139.phh (variant = 'NT')
#   ✓ Keeping: 140.phh (variant = 'NT')
#   ✓ Keeping: 141.phh (variant = 'NT')
#   ✓ Keeping: 142.phh (variant = 'NT')
#   ✓ Keeping: 143.phh (variant = 'NT')
#   ✓ Keeping: 144.phh (variant = 'NT')
#   ✓ Keeping: 145.phh (variant = 'NT')
#   ✓ Keeping: 146.phh (variant = 'NT')
#   ✓ Keeping: 147.phh (variant = 'NT')
#   ✓ Keeping: 148.phh (variant = 'NT')
#   ✓ Keeping: 149.phh (variant = 'NT')
#   ✓ Keeping: 150.phh (variant = 'NT')
#   ✓ Keeping: 151.phh (variant = 'NT')
#   ✓ Keeping: 152.phh (variant = 'NT')
#   ✓ Keeping: 153.phh (variant = 'NT')
#   ✓ Keeping: 154.phh (variant = 'NT')
#   ✓ Keeping: 155.phh (variant = 'NT')
#   ✓ Keeping: 156.phh (variant = 'NT')
#   ✓ Keeping: 146.phh (variant = 'NT')
#   ✓ Keeping: 147.phh (variant = 'NT')
#   ✓ Keeping: 148.phh (variant = 'NT')
#   ✓ Keeping: 149.phh (variant = 'NT')
#   ✓ Keeping: 150.phh (variant = 'NT')
#   ✓ Keeping: 151.phh (variant = 'NT')
#   ✓ Keeping: 152.phh (variant = 'NT')
#   ✓ Keeping: 153.phh (variant = 'NT')
#   ✓ Keeping: 154.phh (variant = 'NT')
#   ✓ Keeping: 155.phh (variant = 'NT')
#   ✓ Keeping: 156.phh (variant = 'NT')
#   ✓ Keeping: 157.phh (variant = 'NT')
#   ✓ Keeping: 158.phh (variant = 'NT')
#   ✓ Keeping: 159.phh (variant = 'NT')
#   ✓ Keeping: 160.phh (variant = 'NT')
#   ✓ Keeping: 161.phh (variant = 'NT')
#   ✓ Keeping: 162.phh (variant = 'NT')
#   ✓ Keeping: 163.phh (variant = 'NT')
#   ✓ Keeping: 164.phh (variant = 'NT')
#   ✓ Keeping: 165.phh (variant = 'NT')
#   ✓ Keeping: 157.phh (variant = 'NT')
#   ✓ Keeping: 158.phh (variant = 'NT')
#   ✓ Keeping: 159.phh (variant = 'NT')
#   ✓ Keeping: 160.phh (variant = 'NT')
#   ✓ Keeping: 161.phh (variant = 'NT')
#   ✓ Keeping: 162.phh (variant = 'NT')
#   ✓ Keeping: 163.phh (variant = 'NT')
#   ✓ Keeping: 164.phh (variant = 'NT')
#   ✓ Keeping: 165.phh (variant = 'NT')
#   ✓ Keeping: 166.phh (variant = 'NT')
#   ✓ Keeping: 167.phh (variant = 'NT')
#   ✓ Keeping: 168.phh (variant = 'NT')
#   ✓ Keeping: 169.phh (variant = 'NT')
#   ✓ Keeping: 170.phh (variant = 'NT')
#   ✓ Keeping: 171.phh (variant = 'NT')
#   ✓ Keeping: 172.phh (variant = 'NT')
#   ✓ Keeping: 173.phh (variant = 'NT')
#   ✓ Keeping: 174.phh (variant = 'NT')
#   ✓ Keeping: 175.phh (variant = 'NT')
#   ✓ Keeping: 176.phh (variant = 'NT')
#   ✓ Keeping: 177.phh (variant = 'NT')
#   ✓ Keeping: 178.phh (variant = 'NT')
#   ✓ Keeping: 179.phh (variant = 'NT')
#   ✓ Keeping: 166.phh (variant = 'NT')
#   ✓ Keeping: 167.phh (variant = 'NT')
#   ✓ Keeping: 168.phh (variant = 'NT')
#   ✓ Keeping: 169.phh (variant = 'NT')
#   ✓ Keeping: 170.phh (variant = 'NT')
#   ✓ Keeping: 171.phh (variant = 'NT')
#   ✓ Keeping: 172.phh (variant = 'NT')
#   ✓ Keeping: 173.phh (variant = 'NT')
#   ✓ Keeping: 174.phh (variant = 'NT')
#   ✓ Keeping: 175.phh (variant = 'NT')
#   ✓ Keeping: 176.phh (variant = 'NT')
#   ✓ Keeping: 177.phh (variant = 'NT')
#   ✓ Keeping: 178.phh (variant = 'NT')
#   ✓ Keeping: 179.phh (variant = 'NT')
#   ✓ Keeping: 180.phh (variant = 'NT')
#   ✓ Keeping: 181.phh (variant = 'NT')
#   ✓ Keeping: 182.phh (variant = 'NT')
#   ✓ Keeping: 183.phh (variant = 'NT')
#   ✓ Keeping: 71.phh (variant = 'NT')
#   ✓ Keeping: 72.phh (variant = 'NT')
#   ✓ Keeping: 73.phh (variant = 'NT')
#   ✓ Keeping: 74.phh (variant = 'NT')
#   ✓ Keeping: 75.phh (variant = 'NT')
#   ✓ Keeping: 76.phh (variant = 'NT')
#   ✓ Keeping: 77.phh (variant = 'NT')
#   ✓ Keeping: 180.phh (variant = 'NT')
#   ✓ Keeping: 181.phh (variant = 'NT')
#   ✓ Keeping: 182.phh (variant = 'NT')
#   ✓ Keeping: 183.phh (variant = 'NT')
#   ✓ Keeping: 71.phh (variant = 'NT')
#   ✓ Keeping: 72.phh (variant = 'NT')
#   ✓ Keeping: 73.phh (variant = 'NT')
#   ✓ Keeping: 74.phh (variant = 'NT')
#   ✓ Keeping: 75.phh (variant = 'NT')
#   ✓ Keeping: 76.phh (variant = 'NT')
#   ✓ Keeping: 77.phh (variant = 'NT')
#   ✓ Keeping: 78.phh (variant = 'NT')
#   ✓ Keeping: 79.phh (variant = 'NT')
#   ✓ Keeping: 80.phh (variant = 'NT')
#   ✓ Keeping: 81.phh (variant = 'NT')
#   ✓ Keeping: 82.phh (variant = 'NT')
#   ✓ Keeping: 83.phh (variant = 'NT')
#   ✓ Keeping: 84.phh (variant = 'NT')
#   ✓ Keeping: 78.phh (variant = 'NT')
#   ✓ Keeping: 79.phh (variant = 'NT')
#   ✓ Keeping: 80.phh (variant = 'NT')
#   ✓ Keeping: 81.phh (variant = 'NT')
#   ✓ Keeping: 82.phh (variant = 'NT')
#   ✓ Keeping: 83.phh (variant = 'NT')
#   ✓ Keeping: 84.phh (variant = 'NT')
#   ✓ Keeping: 85.phh (variant = 'NT')
#   ✓ Keeping: 86.phh (variant = 'NT')
#   ✓ Keeping: 87.phh (variant = 'NT')
#   ✓ Keeping: 88.phh (variant = 'NT')
#   ✓ Keeping: 89.phh (variant = 'NT')
#   ✓ Keeping: 90.phh (variant = 'NT')
#   ✓ Keeping: 91.phh (variant = 'NT')
#   ✓ Keeping: 92.phh (variant = 'NT')
#   ✓ Keeping: 93.phh (variant = 'NT')
#   ✓ Keeping: 94.phh (variant = 'NT')
#   ✓ Keeping: 95.phh (variant = 'NT')
#   ✓ Keeping: 96.phh (variant = 'NT')
#   ✓ Keeping: 85.phh (variant = 'NT')
#   ✓ Keeping: 86.phh (variant = 'NT')
#   ✓ Keeping: 87.phh (variant = 'NT')
#   ✓ Keeping: 88.phh (variant = 'NT')
#   ✓ Keeping: 89.phh (variant = 'NT')
#   ✓ Keeping: 90.phh (variant = 'NT')
#   ✓ Keeping: 91.phh (variant = 'NT')
#   ✓ Keeping: 92.phh (variant = 'NT')
#   ✓ Keeping: 93.phh (variant = 'NT')
#   ✓ Keeping: 94.phh (variant = 'NT')
#   ✓ Keeping: 95.phh (variant = 'NT')
#   ✓ Keeping: 96.phh (variant = 'NT')
#   ✓ Keeping: 97.phh (variant = 'NT')
#   ✓ Keeping: 98.phh (variant = 'NT')
#   ✓ Keeping: 99.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\101
# Found 92 .phh files
#   ✓ Keeping: 0.phh (variant = 'NT')
#   ✓ Keeping: 1.phh (variant = 'NT')
#   ✓ Keeping: 10.phh (variant = 'NT')
#   ✓ Keeping: 11.phh (variant = 'NT')
#   ✓ Keeping: 12.phh (variant = 'NT')
#   ✓ Keeping: 13.phh (variant = 'NT')
#   ✓ Keeping: 14.phh (variant = 'NT')
#   ✓ Keeping: 15.phh (variant = 'NT')
#   ✓ Keeping: 16.phh (variant = 'NT')
#   ✓ Keeping: 17.phh (variant = 'NT')
#   ✓ Keeping: 18.phh (variant = 'NT')
#   ✓ Keeping: 97.phh (variant = 'NT')
#   ✓ Keeping: 98.phh (variant = 'NT')
#   ✓ Keeping: 99.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\101
# Found 92 .phh files
#   ✓ Keeping: 0.phh (variant = 'NT')
#   ✓ Keeping: 1.phh (variant = 'NT')
#   ✓ Keeping: 10.phh (variant = 'NT')
#   ✓ Keeping: 11.phh (variant = 'NT')
#   ✓ Keeping: 12.phh (variant = 'NT')
#   ✓ Keeping: 13.phh (variant = 'NT')
#   ✓ Keeping: 14.phh (variant = 'NT')
#   ✓ Keeping: 15.phh (variant = 'NT')
#   ✓ Keeping: 16.phh (variant = 'NT')
#   ✓ Keeping: 17.phh (variant = 'NT')
#   ✓ Keeping: 18.phh (variant = 'NT')
#   ✓ Keeping: 19.phh (variant = 'NT')
#   ✓ Keeping: 2.phh (variant = 'NT')
#   ✓ Keeping: 20.phh (variant = 'NT')
#   ✓ Keeping: 21.phh (variant = 'NT')
#   ✓ Keeping: 22.phh (variant = 'NT')
#   ✓ Keeping: 23.phh (variant = 'NT')
#   ✓ Keeping: 24.phh (variant = 'NT')
#   ✓ Keeping: 25.phh (variant = 'NT')
#   ✓ Keeping: 26.phh (variant = 'NT')
#   ✓ Keeping: 27.phh (variant = 'NT')
#   ✓ Keeping: 28.phh (variant = 'NT')
#   ✓ Keeping: 29.phh (variant = 'NT')
#   ✓ Keeping: 19.phh (variant = 'NT')
#   ✓ Keeping: 2.phh (variant = 'NT')
#   ✓ Keeping: 20.phh (variant = 'NT')
#   ✓ Keeping: 21.phh (variant = 'NT')
#   ✓ Keeping: 22.phh (variant = 'NT')
#   ✓ Keeping: 23.phh (variant = 'NT')
#   ✓ Keeping: 24.phh (variant = 'NT')
#   ✓ Keeping: 25.phh (variant = 'NT')
#   ✓ Keeping: 26.phh (variant = 'NT')
#   ✓ Keeping: 27.phh (variant = 'NT')
#   ✓ Keeping: 28.phh (variant = 'NT')
#   ✓ Keeping: 29.phh (variant = 'NT')
#   ✓ Keeping: 3.phh (variant = 'NT')
#   ✓ Keeping: 30.phh (variant = 'NT')
#   ✓ Keeping: 31.phh (variant = 'NT')
#   ✓ Keeping: 32.phh (variant = 'NT')
#   ✓ Keeping: 33.phh (variant = 'NT')
#   ✓ Keeping: 34.phh (variant = 'NT')
#   ✓ Keeping: 35.phh (variant = 'NT')
#   ✓ Keeping: 36.phh (variant = 'NT')
#   ✓ Keeping: 37.phh (variant = 'NT')
#   ✓ Keeping: 38.phh (variant = 'NT')
#   ✓ Keeping: 3.phh (variant = 'NT')
#   ✓ Keeping: 30.phh (variant = 'NT')
#   ✓ Keeping: 31.phh (variant = 'NT')
#   ✓ Keeping: 32.phh (variant = 'NT')
#   ✓ Keeping: 33.phh (variant = 'NT')
#   ✓ Keeping: 34.phh (variant = 'NT')
#   ✓ Keeping: 35.phh (variant = 'NT')
#   ✓ Keeping: 36.phh (variant = 'NT')
#   ✓ Keeping: 37.phh (variant = 'NT')
#   ✓ Keeping: 38.phh (variant = 'NT')
#   ✓ Keeping: 39.phh (variant = 'NT')
#   ✓ Keeping: 4.phh (variant = 'NT')
#   ✓ Keeping: 40.phh (variant = 'NT')
#   ✓ Keeping: 41.phh (variant = 'NT')
#   ✓ Keeping: 42.phh (variant = 'NT')
#   ✓ Keeping: 43.phh (variant = 'NT')
#   ✓ Keeping: 44.phh (variant = 'NT')
#   ✓ Keeping: 45.phh (variant = 'NT')
#   ✓ Keeping: 46.phh (variant = 'NT')
#   ✓ Keeping: 47.phh (variant = 'NT')
#   ✓ Keeping: 48.phh (variant = 'NT')
#   ✓ Keeping: 49.phh (variant = 'NT')
#   ✓ Keeping: 39.phh (variant = 'NT')
#   ✓ Keeping: 4.phh (variant = 'NT')
#   ✓ Keeping: 40.phh (variant = 'NT')
#   ✓ Keeping: 41.phh (variant = 'NT')
#   ✓ Keeping: 42.phh (variant = 'NT')
#   ✓ Keeping: 43.phh (variant = 'NT')
#   ✓ Keeping: 44.phh (variant = 'NT')
#   ✓ Keeping: 45.phh (variant = 'NT')
#   ✓ Keeping: 46.phh (variant = 'NT')
#   ✓ Keeping: 47.phh (variant = 'NT')
#   ✓ Keeping: 48.phh (variant = 'NT')
#   ✓ Keeping: 49.phh (variant = 'NT')
#   ✓ Keeping: 5.phh (variant = 'NT')
#   ✓ Keeping: 50.phh (variant = 'NT')
#   ✓ Keeping: 51.phh (variant = 'NT')
#   ✓ Keeping: 52.phh (variant = 'NT')
#   ✓ Keeping: 53.phh (variant = 'NT')
#   ✓ Keeping: 54.phh (variant = 'NT')
#   ✓ Keeping: 55.phh (variant = 'NT')
#   ✓ Keeping: 56.phh (variant = 'NT')
#   ✓ Keeping: 57.phh (variant = 'NT')
#   ✓ Keeping: 58.phh (variant = 'NT')
#   ✓ Keeping: 5.phh (variant = 'NT')
#   ✓ Keeping: 50.phh (variant = 'NT')
#   ✓ Keeping: 51.phh (variant = 'NT')
#   ✓ Keeping: 52.phh (variant = 'NT')
#   ✓ Keeping: 53.phh (variant = 'NT')
#   ✓ Keeping: 54.phh (variant = 'NT')
#   ✓ Keeping: 55.phh (variant = 'NT')
#   ✓ Keeping: 56.phh (variant = 'NT')
#   ✓ Keeping: 57.phh (variant = 'NT')
#   ✓ Keeping: 58.phh (variant = 'NT')
#   ✓ Keeping: 59.phh (variant = 'NT')
#   ✓ Keeping: 6.phh (variant = 'NT')
#   ✓ Keeping: 60.phh (variant = 'NT')
#   ✓ Keeping: 61.phh (variant = 'NT')
#   ✓ Keeping: 62.phh (variant = 'NT')
#   ✓ Keeping: 63.phh (variant = 'NT')
#   ✓ Keeping: 64.phh (variant = 'NT')
#   ✓ Keeping: 65.phh (variant = 'NT')
#   ✓ Keeping: 66.phh (variant = 'NT')
#   ✓ Keeping: 67.phh (variant = 'NT')
#   ✓ Keeping: 68.phh (variant = 'NT')
#   ✓ Keeping: 69.phh (variant = 'NT')
#   ✓ Keeping: 7.phh (variant = 'NT')
#   ✓ Keeping: 59.phh (variant = 'NT')
#   ✓ Keeping: 6.phh (variant = 'NT')
#   ✓ Keeping: 60.phh (variant = 'NT')
#   ✓ Keeping: 61.phh (variant = 'NT')
#   ✓ Keeping: 62.phh (variant = 'NT')
#   ✓ Keeping: 63.phh (variant = 'NT')
#   ✓ Keeping: 64.phh (variant = 'NT')
#   ✓ Keeping: 65.phh (variant = 'NT')
#   ✓ Keeping: 66.phh (variant = 'NT')
#   ✓ Keeping: 67.phh (variant = 'NT')
#   ✓ Keeping: 68.phh (variant = 'NT')
#   ✓ Keeping: 69.phh (variant = 'NT')
#   ✓ Keeping: 7.phh (variant = 'NT')
#   ✓ Keeping: 70.phh (variant = 'NT')
#   ✓ Keeping: 71.phh (variant = 'NT')
#   ✓ Keeping: 72.phh (variant = 'NT')
#   ✓ Keeping: 73.phh (variant = 'NT')
#   ✓ Keeping: 74.phh (variant = 'NT')
#   ✓ Keeping: 75.phh (variant = 'NT')
#   ✓ Keeping: 76.phh (variant = 'NT')
#   ✓ Keeping: 77.phh (variant = 'NT')
#   ✓ Keeping: 78.phh (variant = 'NT')
#   ✓ Keeping: 79.phh (variant = 'NT')
#   ✓ Keeping: 70.phh (variant = 'NT')
#   ✓ Keeping: 71.phh (variant = 'NT')
#   ✓ Keeping: 72.phh (variant = 'NT')
#   ✓ Keeping: 73.phh (variant = 'NT')
#   ✓ Keeping: 74.phh (variant = 'NT')
#   ✓ Keeping: 75.phh (variant = 'NT')
#   ✓ Keeping: 76.phh (variant = 'NT')
#   ✓ Keeping: 77.phh (variant = 'NT')
#   ✓ Keeping: 78.phh (variant = 'NT')
#   ✓ Keeping: 79.phh (variant = 'NT')
#   ✓ Keeping: 8.phh (variant = 'NT')
#   ✓ Keeping: 80.phh (variant = 'NT')
#   ✓ Keeping: 81.phh (variant = 'NT')
#   ✓ Keeping: 82.phh (variant = 'NT')
#   ✓ Keeping: 83.phh (variant = 'NT')
#   ✓ Keeping: 84.phh (variant = 'NT')
#   ✓ Keeping: 85.phh (variant = 'NT')
#   ✓ Keeping: 86.phh (variant = 'NT')
#   ✓ Keeping: 8.phh (variant = 'NT')
#   ✓ Keeping: 80.phh (variant = 'NT')
#   ✓ Keeping: 81.phh (variant = 'NT')
#   ✓ Keeping: 82.phh (variant = 'NT')
#   ✓ Keeping: 83.phh (variant = 'NT')
#   ✓ Keeping: 84.phh (variant = 'NT')
#   ✓ Keeping: 85.phh (variant = 'NT')
#   ✓ Keeping: 86.phh (variant = 'NT')
#   ✓ Keeping: 87.phh (variant = 'NT')
#   ✓ Keeping: 88.phh (variant = 'NT')
#   ✓ Keeping: 89.phh (variant = 'NT')
#   ✓ Keeping: 9.phh (variant = 'NT')
#   ✓ Keeping: 90.phh (variant = 'NT')
#   ✓ Keeping: 91.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\101b
# Found 3 .phh files
#   ✓ Keeping: 92.phh (variant = 'NT')
#   ✓ Keeping: 93.phh (variant = 'NT')
#   ✓ Keeping: 94.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\102
# Found 73 .phh files
#   ✓ Keeping: 0.phh (variant = 'NT')
#   ✓ Keeping: 1.phh (variant = 'NT')
#   ✓ Keeping: 10.phh (variant = 'NT')
#   ✓ Keeping: 11.phh (variant = 'NT')
#   ✓ Keeping: 87.phh (variant = 'NT')
#   ✓ Keeping: 88.phh (variant = 'NT')
#   ✓ Keeping: 89.phh (variant = 'NT')
#   ✓ Keeping: 9.phh (variant = 'NT')
#   ✓ Keeping: 90.phh (variant = 'NT')
#   ✓ Keeping: 91.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\101b
# Found 3 .phh files
#   ✓ Keeping: 92.phh (variant = 'NT')
#   ✓ Keeping: 93.phh (variant = 'NT')
#   ✓ Keeping: 94.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\102
# Found 73 .phh files
#   ✓ Keeping: 0.phh (variant = 'NT')
#   ✓ Keeping: 1.phh (variant = 'NT')
#   ✓ Keeping: 10.phh (variant = 'NT')
#   ✓ Keeping: 11.phh (variant = 'NT')
#   ✓ Keeping: 12.phh (variant = 'NT')
#   ✓ Keeping: 13.phh (variant = 'NT')
#   ✓ Keeping: 14.phh (variant = 'NT')
#   ✓ Keeping: 15.phh (variant = 'NT')
#   ✓ Keeping: 16.phh (variant = 'NT')
#   ✓ Keeping: 17.phh (variant = 'NT')
#   ✓ Keeping: 18.phh (variant = 'NT')
#   ✓ Keeping: 19.phh (variant = 'NT')
#   ✓ Keeping: 2.phh (variant = 'NT')
#   ✓ Keeping: 12.phh (variant = 'NT')
#   ✓ Keeping: 13.phh (variant = 'NT')
#   ✓ Keeping: 14.phh (variant = 'NT')
#   ✓ Keeping: 15.phh (variant = 'NT')
#   ✓ Keeping: 16.phh (variant = 'NT')
#   ✓ Keeping: 17.phh (variant = 'NT')
#   ✓ Keeping: 18.phh (variant = 'NT')
#   ✓ Keeping: 19.phh (variant = 'NT')
#   ✓ Keeping: 2.phh (variant = 'NT')
#   ✓ Keeping: 20.phh (variant = 'NT')
#   ✓ Keeping: 21.phh (variant = 'NT')
#   ✓ Keeping: 22.phh (variant = 'NT')
#   ✓ Keeping: 23.phh (variant = 'NT')
#   ✓ Keeping: 24.phh (variant = 'NT')
#   ✓ Keeping: 25.phh (variant = 'NT')
#   ✓ Keeping: 26.phh (variant = 'NT')
#   ✓ Keeping: 27.phh (variant = 'NT')
#   ✓ Keeping: 28.phh (variant = 'NT')
#   ✓ Keeping: 29.phh (variant = 'NT')
#   ✓ Keeping: 20.phh (variant = 'NT')
#   ✓ Keeping: 21.phh (variant = 'NT')
#   ✓ Keeping: 22.phh (variant = 'NT')
#   ✓ Keeping: 23.phh (variant = 'NT')
#   ✓ Keeping: 24.phh (variant = 'NT')
#   ✓ Keeping: 25.phh (variant = 'NT')
#   ✓ Keeping: 26.phh (variant = 'NT')
#   ✓ Keeping: 27.phh (variant = 'NT')
#   ✓ Keeping: 28.phh (variant = 'NT')
#   ✓ Keeping: 29.phh (variant = 'NT')
#   ✓ Keeping: 3.phh (variant = 'NT')
#   ✓ Keeping: 30.phh (variant = 'NT')
#   ✓ Keeping: 31.phh (variant = 'NT')
#   ✓ Keeping: 32.phh (variant = 'NT')
#   ✓ Keeping: 33.phh (variant = 'NT')
#   ✓ Keeping: 34.phh (variant = 'NT')
#   ✓ Keeping: 35.phh (variant = 'NT')
#   ✓ Keeping: 36.phh (variant = 'NT')
#   ✓ Keeping: 37.phh (variant = 'NT')
#   ✓ Keeping: 3.phh (variant = 'NT')
#   ✓ Keeping: 30.phh (variant = 'NT')
#   ✓ Keeping: 31.phh (variant = 'NT')
#   ✓ Keeping: 32.phh (variant = 'NT')
#   ✓ Keeping: 33.phh (variant = 'NT')
#   ✓ Keeping: 34.phh (variant = 'NT')
#   ✓ Keeping: 35.phh (variant = 'NT')
#   ✓ Keeping: 36.phh (variant = 'NT')
#   ✓ Keeping: 37.phh (variant = 'NT')
#   ✓ Keeping: 38.phh (variant = 'NT')
#   ✓ Keeping: 39.phh (variant = 'NT')
#   ✓ Keeping: 4.phh (variant = 'NT')
#   ✓ Keeping: 40.phh (variant = 'NT')
#   ✓ Keeping: 41.phh (variant = 'NT')
#   ✓ Keeping: 42.phh (variant = 'NT')
#   ✓ Keeping: 43.phh (variant = 'NT')
#   ✓ Keeping: 44.phh (variant = 'NT')
#   ✓ Keeping: 38.phh (variant = 'NT')
#   ✓ Keeping: 39.phh (variant = 'NT')
#   ✓ Keeping: 4.phh (variant = 'NT')
#   ✓ Keeping: 40.phh (variant = 'NT')
#   ✓ Keeping: 41.phh (variant = 'NT')
#   ✓ Keeping: 42.phh (variant = 'NT')
#   ✓ Keeping: 43.phh (variant = 'NT')
#   ✓ Keeping: 44.phh (variant = 'NT')
#   ✓ Keeping: 45.phh (variant = 'NT')
#   ✓ Keeping: 46.phh (variant = 'NT')
#   ✓ Keeping: 47.phh (variant = 'NT')
#   ✓ Keeping: 48.phh (variant = 'NT')
#   ✓ Keeping: 49.phh (variant = 'NT')
#   ✓ Keeping: 5.phh (variant = 'NT')
#   ✓ Keeping: 50.phh (variant = 'NT')
#   ✓ Keeping: 51.phh (variant = 'NT')
#   ✓ Keeping: 52.phh (variant = 'NT')
#   ✓ Keeping: 53.phh (variant = 'NT')
#   ✓ Keeping: 54.phh (variant = 'NT')
#   ✓ Keeping: 55.phh (variant = 'NT')
#   ✓ Keeping: 45.phh (variant = 'NT')
#   ✓ Keeping: 46.phh (variant = 'NT')
#   ✓ Keeping: 47.phh (variant = 'NT')
#   ✓ Keeping: 48.phh (variant = 'NT')
#   ✓ Keeping: 49.phh (variant = 'NT')
#   ✓ Keeping: 5.phh (variant = 'NT')
#   ✓ Keeping: 50.phh (variant = 'NT')
#   ✓ Keeping: 51.phh (variant = 'NT')
#   ✓ Keeping: 52.phh (variant = 'NT')
#   ✓ Keeping: 53.phh (variant = 'NT')
#   ✓ Keeping: 54.phh (variant = 'NT')
#   ✓ Keeping: 55.phh (variant = 'NT')
#   ✓ Keeping: 56.phh (variant = 'NT')
#   ✓ Keeping: 57.phh (variant = 'NT')
#   ✓ Keeping: 58.phh (variant = 'NT')
#   ✓ Keeping: 59.phh (variant = 'NT')
#   ✓ Keeping: 6.phh (variant = 'NT')
#   ✓ Keeping: 60.phh (variant = 'NT')
#   ✓ Keeping: 61.phh (variant = 'NT')
#   ✓ Keeping: 62.phh (variant = 'NT')
#   ✓ Keeping: 63.phh (variant = 'NT')
#   ✓ Keeping: 64.phh (variant = 'NT')
#   ✓ Keeping: 56.phh (variant = 'NT')
#   ✓ Keeping: 57.phh (variant = 'NT')
#   ✓ Keeping: 58.phh (variant = 'NT')
#   ✓ Keeping: 59.phh (variant = 'NT')
#   ✓ Keeping: 6.phh (variant = 'NT')
#   ✓ Keeping: 60.phh (variant = 'NT')
#   ✓ Keeping: 61.phh (variant = 'NT')
#   ✓ Keeping: 62.phh (variant = 'NT')
#   ✓ Keeping: 63.phh (variant = 'NT')
#   ✓ Keeping: 64.phh (variant = 'NT')
#   ✓ Keeping: 65.phh (variant = 'NT')
#   ✓ Keeping: 66.phh (variant = 'NT')
#   ✓ Keeping: 67.phh (variant = 'NT')
#   ✓ Keeping: 68.phh (variant = 'NT')
#   ✓ Keeping: 69.phh (variant = 'NT')
#   ✓ Keeping: 7.phh (variant = 'NT')
#   ✓ Keeping: 70.phh (variant = 'NT')
#   ✓ Keeping: 71.phh (variant = 'NT')
#   ✓ Keeping: 72.phh (variant = 'NT')
#   ✓ Keeping: 8.phh (variant = 'NT')
#   ✓ Keeping: 9.phh (variant = 'NT')
#   ✓ Keeping: 65.phh (variant = 'NT')
#   ✓ Keeping: 66.phh (variant = 'NT')
#   ✓ Keeping: 67.phh (variant = 'NT')
#   ✓ Keeping: 68.phh (variant = 'NT')
#   ✓ Keeping: 69.phh (variant = 'NT')
#   ✓ Keeping: 7.phh (variant = 'NT')
#   ✓ Keeping: 70.phh (variant = 'NT')
#   ✓ Keeping: 71.phh (variant = 'NT')
#   ✓ Keeping: 72.phh (variant = 'NT')
#   ✓ Keeping: 8.phh (variant = 'NT')
#   ✓ Keeping: 9.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\102b
# Found 47 .phh files
#   ✓ Keeping: 100.phh (variant = 'NT')
#   ✓ Keeping: 101.phh (variant = 'NT')
#   ✓ Keeping: 102.phh (variant = 'NT')
#   ✓ Keeping: 103.phh (variant = 'NT')
#   ✓ Keeping: 104.phh (variant = 'NT')
#   ✓ Keeping: 105.phh (variant = 'NT')
#   ✓ Keeping: 106.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\102b
# Found 47 .phh files
#   ✓ Keeping: 100.phh (variant = 'NT')
#   ✓ Keeping: 101.phh (variant = 'NT')
#   ✓ Keeping: 102.phh (variant = 'NT')
#   ✓ Keeping: 103.phh (variant = 'NT')
#   ✓ Keeping: 104.phh (variant = 'NT')
#   ✓ Keeping: 105.phh (variant = 'NT')
#   ✓ Keeping: 106.phh (variant = 'NT')
#   ✓ Keeping: 107.phh (variant = 'NT')
#   ✓ Keeping: 108.phh (variant = 'NT')
#   ✓ Keeping: 109.phh (variant = 'NT')
#   ✓ Keeping: 110.phh (variant = 'NT')
#   ✓ Keeping: 111.phh (variant = 'NT')
#   ✓ Keeping: 112.phh (variant = 'NT')
#   ✓ Keeping: 113.phh (variant = 'NT')
#   ✓ Keeping: 114.phh (variant = 'NT')
#   ✓ Keeping: 115.phh (variant = 'NT')
#   ✓ Keeping: 116.phh (variant = 'NT')
#   ✓ Keeping: 117.phh (variant = 'NT')
#   ✓ Keeping: 118.phh (variant = 'NT')
#   ✓ Keeping: 107.phh (variant = 'NT')
#   ✓ Keeping: 108.phh (variant = 'NT')
#   ✓ Keeping: 109.phh (variant = 'NT')
#   ✓ Keeping: 110.phh (variant = 'NT')
#   ✓ Keeping: 111.phh (variant = 'NT')
#   ✓ Keeping: 112.phh (variant = 'NT')
#   ✓ Keeping: 113.phh (variant = 'NT')
#   ✓ Keeping: 114.phh (variant = 'NT')
#   ✓ Keeping: 115.phh (variant = 'NT')
#   ✓ Keeping: 116.phh (variant = 'NT')
#   ✓ Keeping: 117.phh (variant = 'NT')
#   ✓ Keeping: 118.phh (variant = 'NT')
#   ✓ Keeping: 119.phh (variant = 'NT')
#   ✓ Keeping: 73.phh (variant = 'NT')
#   ✓ Keeping: 74.phh (variant = 'NT')
#   ✓ Keeping: 75.phh (variant = 'NT')
#   ✓ Keeping: 76.phh (variant = 'NT')
#   ✓ Keeping: 77.phh (variant = 'NT')
#   ✓ Keeping: 78.phh (variant = 'NT')
#   ✓ Keeping: 79.phh (variant = 'NT')
#   ✓ Keeping: 80.phh (variant = 'NT')
#   ✓ Keeping: 81.phh (variant = 'NT')
#   ✓ Keeping: 82.phh (variant = 'NT')
#   ✓ Keeping: 83.phh (variant = 'NT')
#   ✓ Keeping: 119.phh (variant = 'NT')
#   ✓ Keeping: 73.phh (variant = 'NT')
#   ✓ Keeping: 74.phh (variant = 'NT')
#   ✓ Keeping: 75.phh (variant = 'NT')
#   ✓ Keeping: 76.phh (variant = 'NT')
#   ✓ Keeping: 77.phh (variant = 'NT')
#   ✓ Keeping: 78.phh (variant = 'NT')
#   ✓ Keeping: 79.phh (variant = 'NT')
#   ✓ Keeping: 80.phh (variant = 'NT')
#   ✓ Keeping: 81.phh (variant = 'NT')
#   ✓ Keeping: 82.phh (variant = 'NT')
#   ✓ Keeping: 83.phh (variant = 'NT')
#   ✓ Keeping: 84.phh (variant = 'NT')
#   ✓ Keeping: 85.phh (variant = 'NT')
#   ✓ Keeping: 86.phh (variant = 'NT')
#   ✓ Keeping: 87.phh (variant = 'NT')
#   ✓ Keeping: 88.phh (variant = 'NT')
#   ✓ Keeping: 89.phh (variant = 'NT')
#   ✓ Keeping: 90.phh (variant = 'NT')
#   ✓ Keeping: 91.phh (variant = 'NT')
#   ✓ Keeping: 84.phh (variant = 'NT')
#   ✓ Keeping: 85.phh (variant = 'NT')
#   ✓ Keeping: 86.phh (variant = 'NT')
#   ✓ Keeping: 87.phh (variant = 'NT')
#   ✓ Keeping: 88.phh (variant = 'NT')
#   ✓ Keeping: 89.phh (variant = 'NT')
#   ✓ Keeping: 90.phh (variant = 'NT')
#   ✓ Keeping: 91.phh (variant = 'NT')
#   ✓ Keeping: 92.phh (variant = 'NT')
#   ✓ Keeping: 93.phh (variant = 'NT')
#   ✓ Keeping: 94.phh (variant = 'NT')
#   ✓ Keeping: 95.phh (variant = 'NT')
#   ✓ Keeping: 96.phh (variant = 'NT')
#   ✓ Keeping: 97.phh (variant = 'NT')
#   ✓ Keeping: 98.phh (variant = 'NT')
#   ✓ Keeping: 99.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\103
# Found 67 .phh files
#   ✓ Keeping: 0.phh (variant = 'NT')
#   ✓ Keeping: 1.phh (variant = 'NT')
#   ✓ Keeping: 92.phh (variant = 'NT')
#   ✓ Keeping: 93.phh (variant = 'NT')
#   ✓ Keeping: 94.phh (variant = 'NT')
#   ✓ Keeping: 95.phh (variant = 'NT')
#   ✓ Keeping: 96.phh (variant = 'NT')
#   ✓ Keeping: 97.phh (variant = 'NT')
#   ✓ Keeping: 98.phh (variant = 'NT')
#   ✓ Keeping: 99.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\103
# Found 67 .phh files
#   ✓ Keeping: 0.phh (variant = 'NT')
#   ✓ Keeping: 1.phh (variant = 'NT')
#   ✓ Keeping: 10.phh (variant = 'NT')
#   ✓ Keeping: 11.phh (variant = 'NT')
#   ✓ Keeping: 12.phh (variant = 'NT')
#   ✓ Keeping: 13.phh (variant = 'NT')
#   ✓ Keeping: 14.phh (variant = 'NT')
#   ✓ Keeping: 15.phh (variant = 'NT')
#   ✓ Keeping: 16.phh (variant = 'NT')
#   ✓ Keeping: 17.phh (variant = 'NT')
#   ✓ Keeping: 10.phh (variant = 'NT')
#   ✓ Keeping: 11.phh (variant = 'NT')
#   ✓ Keeping: 12.phh (variant = 'NT')
#   ✓ Keeping: 13.phh (variant = 'NT')
#   ✓ Keeping: 14.phh (variant = 'NT')
#   ✓ Keeping: 15.phh (variant = 'NT')
#   ✓ Keeping: 16.phh (variant = 'NT')
#   ✓ Keeping: 17.phh (variant = 'NT')
#   ✓ Keeping: 18.phh (variant = 'NT')
#   ✓ Keeping: 19.phh (variant = 'NT')
#   ✓ Keeping: 2.phh (variant = 'NT')
#   ✓ Keeping: 20.phh (variant = 'NT')
#   ✓ Keeping: 21.phh (variant = 'NT')
#   ✓ Keeping: 22.phh (variant = 'NT')
#   ✓ Keeping: 23.phh (variant = 'NT')
#   ✓ Keeping: 24.phh (variant = 'NT')
#   ✓ Keeping: 25.phh (variant = 'NT')
#   ✓ Keeping: 18.phh (variant = 'NT')
#   ✓ Keeping: 19.phh (variant = 'NT')
#   ✓ Keeping: 2.phh (variant = 'NT')
#   ✓ Keeping: 20.phh (variant = 'NT')
#   ✓ Keeping: 21.phh (variant = 'NT')
#   ✓ Keeping: 22.phh (variant = 'NT')
#   ✓ Keeping: 23.phh (variant = 'NT')
#   ✓ Keeping: 24.phh (variant = 'NT')
#   ✓ Keeping: 25.phh (variant = 'NT')
#   ✓ Keeping: 26.phh (variant = 'NT')
#   ✓ Keeping: 27.phh (variant = 'NT')
#   ✓ Keeping: 28.phh (variant = 'NT')
#   ✓ Keeping: 29.phh (variant = 'NT')
#   ✓ Keeping: 3.phh (variant = 'NT')
#   ✓ Keeping: 30.phh (variant = 'NT')
#   ✓ Keeping: 31.phh (variant = 'NT')
#   ✓ Keeping: 32.phh (variant = 'NT')
#   ✓ Keeping: 33.phh (variant = 'NT')
#   ✓ Keeping: 26.phh (variant = 'NT')
#   ✓ Keeping: 27.phh (variant = 'NT')
#   ✓ Keeping: 28.phh (variant = 'NT')
#   ✓ Keeping: 29.phh (variant = 'NT')
#   ✓ Keeping: 3.phh (variant = 'NT')
#   ✓ Keeping: 30.phh (variant = 'NT')
#   ✓ Keeping: 31.phh (variant = 'NT')
#   ✓ Keeping: 32.phh (variant = 'NT')
#   ✓ Keeping: 33.phh (variant = 'NT')
#   ✓ Keeping: 34.phh (variant = 'NT')
#   ✓ Keeping: 35.phh (variant = 'NT')
#   ✓ Keeping: 36.phh (variant = 'NT')
#   ✓ Keeping: 37.phh (variant = 'NT')
#   ✓ Keeping: 38.phh (variant = 'NT')
#   ✓ Keeping: 39.phh (variant = 'NT')
#   ✓ Keeping: 4.phh (variant = 'NT')
#   ✓ Keeping: 40.phh (variant = 'NT')
#   ✓ Keeping: 41.phh (variant = 'NT')
#   ✓ Keeping: 42.phh (variant = 'NT')
#   ✓ Keeping: 43.phh (variant = 'NT')
#   ✓ Keeping: 44.phh (variant = 'NT')
#   ✓ Keeping: 34.phh (variant = 'NT')
#   ✓ Keeping: 35.phh (variant = 'NT')
#   ✓ Keeping: 36.phh (variant = 'NT')
#   ✓ Keeping: 37.phh (variant = 'NT')
#   ✓ Keeping: 38.phh (variant = 'NT')
#   ✓ Keeping: 39.phh (variant = 'NT')
#   ✓ Keeping: 4.phh (variant = 'NT')
#   ✓ Keeping: 40.phh (variant = 'NT')
#   ✓ Keeping: 41.phh (variant = 'NT')
#   ✓ Keeping: 42.phh (variant = 'NT')
#   ✓ Keeping: 43.phh (variant = 'NT')
#   ✓ Keeping: 44.phh (variant = 'NT')
#   ✓ Keeping: 45.phh (variant = 'NT')
#   ✓ Keeping: 46.phh (variant = 'NT')
#   ✓ Keeping: 47.phh (variant = 'NT')
#   ✓ Keeping: 48.phh (variant = 'NT')
#   ✓ Keeping: 49.phh (variant = 'NT')
#   ✓ Keeping: 5.phh (variant = 'NT')
#   ✓ Keeping: 50.phh (variant = 'NT')
#   ✓ Keeping: 51.phh (variant = 'NT')
#   ✓ Keeping: 52.phh (variant = 'NT')
#   ✓ Keeping: 53.phh (variant = 'NT')
#   ✓ Keeping: 54.phh (variant = 'NT')
#   ✓ Keeping: 45.phh (variant = 'NT')
#   ✓ Keeping: 46.phh (variant = 'NT')
#   ✓ Keeping: 47.phh (variant = 'NT')
#   ✓ Keeping: 48.phh (variant = 'NT')
#   ✓ Keeping: 49.phh (variant = 'NT')
#   ✓ Keeping: 5.phh (variant = 'NT')
#   ✓ Keeping: 50.phh (variant = 'NT')
#   ✓ Keeping: 51.phh (variant = 'NT')
#   ✓ Keeping: 52.phh (variant = 'NT')
#   ✓ Keeping: 53.phh (variant = 'NT')
#   ✓ Keeping: 54.phh (variant = 'NT')
#   ✓ Keeping: 55.phh (variant = 'NT')
#   ✓ Keeping: 56.phh (variant = 'NT')
#   ✓ Keeping: 57.phh (variant = 'NT')
#   ✓ Keeping: 58.phh (variant = 'NT')
#   ✓ Keeping: 59.phh (variant = 'NT')
#   ✓ Keeping: 6.phh (variant = 'NT')
#   ✓ Keeping: 60.phh (variant = 'NT')
#   ✓ Keeping: 61.phh (variant = 'NT')
#   ✓ Keeping: 62.phh (variant = 'NT')
#   ✓ Keeping: 63.phh (variant = 'NT')
#   ✓ Keeping: 64.phh (variant = 'NT')
#   ✓ Keeping: 65.phh (variant = 'NT')
#   ✓ Keeping: 66.phh (variant = 'NT')
#   ✓ Keeping: 55.phh (variant = 'NT')
#   ✓ Keeping: 56.phh (variant = 'NT')
#   ✓ Keeping: 57.phh (variant = 'NT')
#   ✓ Keeping: 58.phh (variant = 'NT')
#   ✓ Keeping: 59.phh (variant = 'NT')
#   ✓ Keeping: 6.phh (variant = 'NT')
#   ✓ Keeping: 60.phh (variant = 'NT')
#   ✓ Keeping: 61.phh (variant = 'NT')
#   ✓ Keeping: 62.phh (variant = 'NT')
#   ✓ Keeping: 63.phh (variant = 'NT')
#   ✓ Keeping: 64.phh (variant = 'NT')
#   ✓ Keeping: 65.phh (variant = 'NT')
#   ✓ Keeping: 66.phh (variant = 'NT')
#   ✓ Keeping: 7.phh (variant = 'NT')
#   ✓ Keeping: 8.phh (variant = 'NT')
#   ✓ Keeping: 9.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\103b
# Found 111 .phh files
#   ✓ Keeping: 100.phh (variant = 'NT')
#   ✓ Keeping: 101.phh (variant = 'NT')
#   ✓ Keeping: 102.phh (variant = 'NT')
#   ✓ Keeping: 103.phh (variant = 'NT')
#   ✓ Keeping: 104.phh (variant = 'NT')
#   ✓ Keeping: 105.phh (variant = 'NT')
#   ✓ Keeping: 106.phh (variant = 'NT')
#   ✓ Keeping: 107.phh (variant = 'NT')
#   ✓ Keeping: 7.phh (variant = 'NT')
#   ✓ Keeping: 8.phh (variant = 'NT')
#   ✓ Keeping: 9.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\103b
# Found 111 .phh files
#   ✓ Keeping: 100.phh (variant = 'NT')
#   ✓ Keeping: 101.phh (variant = 'NT')
#   ✓ Keeping: 102.phh (variant = 'NT')
#   ✓ Keeping: 103.phh (variant = 'NT')
#   ✓ Keeping: 104.phh (variant = 'NT')
#   ✓ Keeping: 105.phh (variant = 'NT')
#   ✓ Keeping: 106.phh (variant = 'NT')
#   ✓ Keeping: 107.phh (variant = 'NT')
#   ✓ Keeping: 108.phh (variant = 'NT')
#   ✓ Keeping: 109.phh (variant = 'NT')
#   ✓ Keeping: 110.phh (variant = 'NT')
#   ✓ Keeping: 111.phh (variant = 'NT')
#   ✓ Keeping: 112.phh (variant = 'NT')
#   ✓ Keeping: 113.phh (variant = 'NT')
#   ✓ Keeping: 114.phh (variant = 'NT')
#   ✓ Keeping: 115.phh (variant = 'NT')
#   ✓ Keeping: 108.phh (variant = 'NT')
#   ✓ Keeping: 109.phh (variant = 'NT')
#   ✓ Keeping: 110.phh (variant = 'NT')
#   ✓ Keeping: 111.phh (variant = 'NT')
#   ✓ Keeping: 112.phh (variant = 'NT')
#   ✓ Keeping: 113.phh (variant = 'NT')
#   ✓ Keeping: 114.phh (variant = 'NT')
#   ✓ Keeping: 115.phh (variant = 'NT')
#   ✓ Keeping: 116.phh (variant = 'NT')
#   ✓ Keeping: 117.phh (variant = 'NT')
#   ✓ Keeping: 118.phh (variant = 'NT')
#   ✓ Keeping: 119.phh (variant = 'NT')
#   ✓ Keeping: 120.phh (variant = 'NT')
#   ✓ Keeping: 121.phh (variant = 'NT')
#   ✓ Keeping: 122.phh (variant = 'NT')
#   ✓ Keeping: 123.phh (variant = 'NT')
#   ✓ Keeping: 124.phh (variant = 'NT')
#   ✓ Keeping: 116.phh (variant = 'NT')
#   ✓ Keeping: 117.phh (variant = 'NT')
#   ✓ Keeping: 118.phh (variant = 'NT')
#   ✓ Keeping: 119.phh (variant = 'NT')
#   ✓ Keeping: 120.phh (variant = 'NT')
#   ✓ Keeping: 121.phh (variant = 'NT')
#   ✓ Keeping: 122.phh (variant = 'NT')
#   ✓ Keeping: 123.phh (variant = 'NT')
#   ✓ Keeping: 124.phh (variant = 'NT')
#   ✓ Keeping: 125.phh (variant = 'NT')
#   ✓ Keeping: 126.phh (variant = 'NT')
#   ✓ Keeping: 127.phh (variant = 'NT')
#   ✓ Keeping: 128.phh (variant = 'NT')
#   ✓ Keeping: 129.phh (variant = 'NT')
#   ✓ Keeping: 130.phh (variant = 'NT')
#   ✓ Keeping: 131.phh (variant = 'NT')
#   ✓ Keeping: 125.phh (variant = 'NT')
#   ✓ Keeping: 126.phh (variant = 'NT')
#   ✓ Keeping: 127.phh (variant = 'NT')
#   ✓ Keeping: 128.phh (variant = 'NT')
#   ✓ Keeping: 129.phh (variant = 'NT')
#   ✓ Keeping: 130.phh (variant = 'NT')
#   ✓ Keeping: 131.phh (variant = 'NT')
#   ✓ Keeping: 132.phh (variant = 'NT')
#   ✓ Keeping: 133.phh (variant = 'NT')
#   ✓ Keeping: 134.phh (variant = 'NT')
#   ✓ Keeping: 135.phh (variant = 'NT')
#   ✓ Keeping: 136.phh (variant = 'NT')
#   ✓ Keeping: 137.phh (variant = 'NT')
#   ✓ Keeping: 138.phh (variant = 'NT')
#   ✓ Keeping: 139.phh (variant = 'NT')
#   ✓ Keeping: 140.phh (variant = 'NT')
#   ✓ Keeping: 141.phh (variant = 'NT')
#   ✓ Keeping: 142.phh (variant = 'NT')
#   ✓ Keeping: 132.phh (variant = 'NT')
#   ✓ Keeping: 133.phh (variant = 'NT')
#   ✓ Keeping: 134.phh (variant = 'NT')
#   ✓ Keeping: 135.phh (variant = 'NT')
#   ✓ Keeping: 136.phh (variant = 'NT')
#   ✓ Keeping: 137.phh (variant = 'NT')
#   ✓ Keeping: 138.phh (variant = 'NT')
#   ✓ Keeping: 139.phh (variant = 'NT')
#   ✓ Keeping: 140.phh (variant = 'NT')
#   ✓ Keeping: 141.phh (variant = 'NT')
#   ✓ Keeping: 142.phh (variant = 'NT')
#   ✓ Keeping: 143.phh (variant = 'NT')
#   ✓ Keeping: 144.phh (variant = 'NT')
#   ✓ Keeping: 145.phh (variant = 'NT')
#   ✓ Keeping: 146.phh (variant = 'NT')
#   ✓ Keeping: 147.phh (variant = 'NT')
#   ✓ Keeping: 148.phh (variant = 'NT')
#   ✓ Keeping: 149.phh (variant = 'NT')
#   ✓ Keeping: 150.phh (variant = 'NT')
#   ✓ Keeping: 151.phh (variant = 'NT')
#   ✓ Keeping: 152.phh (variant = 'NT')
#   ✓ Keeping: 153.phh (variant = 'NT')
#   ✓ Keeping: 154.phh (variant = 'NT')
#   ✓ Keeping: 155.phh (variant = 'NT')
#   ✓ Keeping: 143.phh (variant = 'NT')
#   ✓ Keeping: 144.phh (variant = 'NT')
#   ✓ Keeping: 145.phh (variant = 'NT')
#   ✓ Keeping: 146.phh (variant = 'NT')
#   ✓ Keeping: 147.phh (variant = 'NT')
#   ✓ Keeping: 148.phh (variant = 'NT')
#   ✓ Keeping: 149.phh (variant = 'NT')
#   ✓ Keeping: 150.phh (variant = 'NT')
#   ✓ Keeping: 151.phh (variant = 'NT')
#   ✓ Keeping: 152.phh (variant = 'NT')
#   ✓ Keeping: 153.phh (variant = 'NT')
#   ✓ Keeping: 154.phh (variant = 'NT')
#   ✓ Keeping: 155.phh (variant = 'NT')
#   ✓ Keeping: 156.phh (variant = 'NT')
#   ✓ Keeping: 157.phh (variant = 'NT')
#   ✓ Keeping: 158.phh (variant = 'NT')
#   ✓ Keeping: 159.phh (variant = 'NT')
#   ✓ Keeping: 160.phh (variant = 'NT')
#   ✓ Keeping: 161.phh (variant = 'NT')
#   ✓ Keeping: 162.phh (variant = 'NT')
#   ✓ Keeping: 163.phh (variant = 'NT')
#   ✓ Keeping: 164.phh (variant = 'NT')
#   ✓ Keeping: 165.phh (variant = 'NT')
#   ✓ Keeping: 156.phh (variant = 'NT')
#   ✓ Keeping: 157.phh (variant = 'NT')
#   ✓ Keeping: 158.phh (variant = 'NT')
#   ✓ Keeping: 159.phh (variant = 'NT')
#   ✓ Keeping: 160.phh (variant = 'NT')
#   ✓ Keeping: 161.phh (variant = 'NT')
#   ✓ Keeping: 162.phh (variant = 'NT')
#   ✓ Keeping: 163.phh (variant = 'NT')
#   ✓ Keeping: 164.phh (variant = 'NT')
#   ✓ Keeping: 165.phh (variant = 'NT')
#   ✓ Keeping: 166.phh (variant = 'NT')
#   ✓ Keeping: 167.phh (variant = 'NT')
#   ✓ Keeping: 168.phh (variant = 'NT')
#   ✓ Keeping: 169.phh (variant = 'NT')
#   ✓ Keeping: 170.phh (variant = 'NT')
#   ✓ Keeping: 171.phh (variant = 'NT')
#   ✓ Keeping: 172.phh (variant = 'NT')
#   ✓ Keeping: 173.phh (variant = 'NT')
#   ✓ Keeping: 174.phh (variant = 'NT')
#   ✓ Keeping: 175.phh (variant = 'NT')
#   ✓ Keeping: 176.phh (variant = 'NT')
#   ✓ Keeping: 166.phh (variant = 'NT')
#   ✓ Keeping: 167.phh (variant = 'NT')
#   ✓ Keeping: 168.phh (variant = 'NT')
#   ✓ Keeping: 169.phh (variant = 'NT')
#   ✓ Keeping: 170.phh (variant = 'NT')
#   ✓ Keeping: 171.phh (variant = 'NT')
#   ✓ Keeping: 172.phh (variant = 'NT')
#   ✓ Keeping: 173.phh (variant = 'NT')
#   ✓ Keeping: 174.phh (variant = 'NT')
#   ✓ Keeping: 175.phh (variant = 'NT')
#   ✓ Keeping: 176.phh (variant = 'NT')
#   ✓ Keeping: 177.phh (variant = 'NT')
#   ✓ Keeping: 67.phh (variant = 'NT')
#   ✓ Keeping: 68.phh (variant = 'NT')
#   ✓ Keeping: 69.phh (variant = 'NT')
#   ✓ Keeping: 70.phh (variant = 'NT')
#   ✓ Keeping: 71.phh (variant = 'NT')
#   ✓ Keeping: 72.phh (variant = 'NT')
#   ✓ Keeping: 73.phh (variant = 'NT')
#   ✓ Keeping: 177.phh (variant = 'NT')
#   ✓ Keeping: 67.phh (variant = 'NT')
#   ✓ Keeping: 68.phh (variant = 'NT')
#   ✓ Keeping: 69.phh (variant = 'NT')
#   ✓ Keeping: 70.phh (variant = 'NT')
#   ✓ Keeping: 71.phh (variant = 'NT')
#   ✓ Keeping: 72.phh (variant = 'NT')
#   ✓ Keeping: 73.phh (variant = 'NT')
#   ✓ Keeping: 74.phh (variant = 'NT')
#   ✓ Keeping: 75.phh (variant = 'NT')
#   ✓ Keeping: 76.phh (variant = 'NT')
#   ✓ Keeping: 77.phh (variant = 'NT')
#   ✓ Keeping: 78.phh (variant = 'NT')
#   ✓ Keeping: 79.phh (variant = 'NT')
#   ✓ Keeping: 80.phh (variant = 'NT')
#   ✓ Keeping: 81.phh (variant = 'NT')
#   ✓ Keeping: 82.phh (variant = 'NT')
#   ✓ Keeping: 83.phh (variant = 'NT')
#   ✓ Keeping: 84.phh (variant = 'NT')
#   ✓ Keeping: 74.phh (variant = 'NT')
#   ✓ Keeping: 75.phh (variant = 'NT')
#   ✓ Keeping: 76.phh (variant = 'NT')
#   ✓ Keeping: 77.phh (variant = 'NT')
#   ✓ Keeping: 78.phh (variant = 'NT')
#   ✓ Keeping: 79.phh (variant = 'NT')
#   ✓ Keeping: 80.phh (variant = 'NT')
#   ✓ Keeping: 81.phh (variant = 'NT')
#   ✓ Keeping: 82.phh (variant = 'NT')
#   ✓ Keeping: 83.phh (variant = 'NT')
#   ✓ Keeping: 84.phh (variant = 'NT')
#   ✓ Keeping: 85.phh (variant = 'NT')
#   ✓ Keeping: 86.phh (variant = 'NT')
#   ✓ Keeping: 87.phh (variant = 'NT')
#   ✓ Keeping: 88.phh (variant = 'NT')
#   ✓ Keeping: 89.phh (variant = 'NT')
#   ✓ Keeping: 90.phh (variant = 'NT')
#   ✓ Keeping: 91.phh (variant = 'NT')
#   ✓ Keeping: 92.phh (variant = 'NT')
#   ✓ Keeping: 93.phh (variant = 'NT')
#   ✓ Keeping: 94.phh (variant = 'NT')
#   ✓ Keeping: 85.phh (variant = 'NT')
#   ✓ Keeping: 86.phh (variant = 'NT')
#   ✓ Keeping: 87.phh (variant = 'NT')
#   ✓ Keeping: 88.phh (variant = 'NT')
#   ✓ Keeping: 89.phh (variant = 'NT')
#   ✓ Keeping: 90.phh (variant = 'NT')
#   ✓ Keeping: 91.phh (variant = 'NT')
#   ✓ Keeping: 92.phh (variant = 'NT')
#   ✓ Keeping: 93.phh (variant = 'NT')
#   ✓ Keeping: 94.phh (variant = 'NT')
#   ✓ Keeping: 95.phh (variant = 'NT')
#   ✓ Keeping: 96.phh (variant = 'NT')
#   ✓ Keeping: 97.phh (variant = 'NT')
#   ✓ Keeping: 98.phh (variant = 'NT')
#   ✓ Keeping: 99.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\104
# Found 110 .phh files
#   ✓ Keeping: 0.phh (variant = 'NT')
#   ✓ Keeping: 1.phh (variant = 'NT')
#   ✓ Keeping: 10.phh (variant = 'NT')
#   ✓ Keeping: 100.phh (variant = 'NT')
#   ✓ Keeping: 101.phh (variant = 'NT')
#   ✓ Keeping: 102.phh (variant = 'NT')
#   ✓ Keeping: 95.phh (variant = 'NT')
#   ✓ Keeping: 96.phh (variant = 'NT')
#   ✓ Keeping: 97.phh (variant = 'NT')
#   ✓ Keeping: 98.phh (variant = 'NT')
#   ✓ Keeping: 99.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\104
# Found 110 .phh files
#   ✓ Keeping: 0.phh (variant = 'NT')
#   ✓ Keeping: 1.phh (variant = 'NT')
#   ✓ Keeping: 10.phh (variant = 'NT')
#   ✓ Keeping: 100.phh (variant = 'NT')
#   ✓ Keeping: 101.phh (variant = 'NT')
#   ✓ Keeping: 102.phh (variant = 'NT')
#   ✓ Keeping: 103.phh (variant = 'NT')
#   ✓ Keeping: 104.phh (variant = 'NT')
#   ✓ Keeping: 105.phh (variant = 'NT')
#   ✓ Keeping: 106.phh (variant = 'NT')
#   ✓ Keeping: 107.phh (variant = 'NT')
#   ✓ Keeping: 108.phh (variant = 'NT')
#   ✓ Keeping: 109.phh (variant = 'NT')
#   ✓ Keeping: 11.phh (variant = 'NT')
#   ✓ Keeping: 12.phh (variant = 'NT')
#   ✓ Keeping: 13.phh (variant = 'NT')
#   ✓ Keeping: 14.phh (variant = 'NT')
#   ✓ Keeping: 103.phh (variant = 'NT')
#   ✓ Keeping: 104.phh (variant = 'NT')
#   ✓ Keeping: 105.phh (variant = 'NT')
#   ✓ Keeping: 106.phh (variant = 'NT')
#   ✓ Keeping: 107.phh (variant = 'NT')
#   ✓ Keeping: 108.phh (variant = 'NT')
#   ✓ Keeping: 109.phh (variant = 'NT')
#   ✓ Keeping: 11.phh (variant = 'NT')
#   ✓ Keeping: 12.phh (variant = 'NT')
#   ✓ Keeping: 13.phh (variant = 'NT')
#   ✓ Keeping: 14.phh (variant = 'NT')
#   ✓ Keeping: 15.phh (variant = 'NT')
#   ✓ Keeping: 16.phh (variant = 'NT')
#   ✓ Keeping: 17.phh (variant = 'NT')
#   ✓ Keeping: 18.phh (variant = 'NT')
#   ✓ Keeping: 19.phh (variant = 'NT')
#   ✓ Keeping: 2.phh (variant = 'NT')
#   ✓ Keeping: 20.phh (variant = 'NT')
#   ✓ Keeping: 21.phh (variant = 'NT')
#   ✓ Keeping: 22.phh (variant = 'NT')
#   ✓ Keeping: 23.phh (variant = 'NT')
#   ✓ Keeping: 24.phh (variant = 'NT')
#   ✓ Keeping: 15.phh (variant = 'NT')
#   ✓ Keeping: 16.phh (variant = 'NT')
#   ✓ Keeping: 17.phh (variant = 'NT')
#   ✓ Keeping: 18.phh (variant = 'NT')
#   ✓ Keeping: 19.phh (variant = 'NT')
#   ✓ Keeping: 2.phh (variant = 'NT')
#   ✓ Keeping: 20.phh (variant = 'NT')
#   ✓ Keeping: 21.phh (variant = 'NT')
#   ✓ Keeping: 22.phh (variant = 'NT')
#   ✓ Keeping: 23.phh (variant = 'NT')
#   ✓ Keeping: 24.phh (variant = 'NT')
#   ✓ Keeping: 25.phh (variant = 'NT')
#   ✓ Keeping: 26.phh (variant = 'NT')
#   ✓ Keeping: 27.phh (variant = 'NT')
#   ✓ Keeping: 28.phh (variant = 'NT')
#   ✓ Keeping: 29.phh (variant = 'NT')
#   ✓ Keeping: 3.phh (variant = 'NT')
#   ✓ Keeping: 30.phh (variant = 'NT')
#   ✓ Keeping: 31.phh (variant = 'NT')
#   ✓ Keeping: 32.phh (variant = 'NT')
#   ✓ Keeping: 33.phh (variant = 'NT')
#   ✓ Keeping: 34.phh (variant = 'NT')
#   ✓ Keeping: 35.phh (variant = 'NT')
#   ✓ Keeping: 36.phh (variant = 'NT')
#   ✓ Keeping: 25.phh (variant = 'NT')
#   ✓ Keeping: 26.phh (variant = 'NT')
#   ✓ Keeping: 27.phh (variant = 'NT')
#   ✓ Keeping: 28.phh (variant = 'NT')
#   ✓ Keeping: 29.phh (variant = 'NT')
#   ✓ Keeping: 3.phh (variant = 'NT')
#   ✓ Keeping: 30.phh (variant = 'NT')
#   ✓ Keeping: 31.phh (variant = 'NT')
#   ✓ Keeping: 32.phh (variant = 'NT')
#   ✓ Keeping: 33.phh (variant = 'NT')
#   ✓ Keeping: 34.phh (variant = 'NT')
#   ✓ Keeping: 35.phh (variant = 'NT')
#   ✓ Keeping: 36.phh (variant = 'NT')
#   ✓ Keeping: 37.phh (variant = 'NT')
#   ✓ Keeping: 38.phh (variant = 'NT')
#   ✓ Keeping: 39.phh (variant = 'NT')
#   ✓ Keeping: 4.phh (variant = 'NT')
#   ✓ Keeping: 40.phh (variant = 'NT')
#   ✓ Keeping: 41.phh (variant = 'NT')
#   ✓ Keeping: 42.phh (variant = 'NT')
#   ✓ Keeping: 43.phh (variant = 'NT')
#   ✓ Keeping: 44.phh (variant = 'NT')
#   ✓ Keeping: 45.phh (variant = 'NT')
#   ✓ Keeping: 46.phh (variant = 'NT')
#   ✓ Keeping: 47.phh (variant = 'NT')
#   ✓ Keeping: 37.phh (variant = 'NT')
#   ✓ Keeping: 38.phh (variant = 'NT')
#   ✓ Keeping: 39.phh (variant = 'NT')
# ...
#   ✓ Keeping: 100.phh (variant = 'NT')
#   ✓ Keeping: 101.phh (variant = 'NT')
#   ✓ Keeping: 102.phh (variant = 'NT')
#   ✓ Keeping: 103.phh (variant = 'NT')
#   ✓ Keeping: 104.phh (variant = 'NT')
#   ✓ Keeping: 105.phh (variant = 'NT')
#   ✓ Keeping: 99.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\pluribus\99
# Found 194 .phh files
#   ✓ Keeping: 0.phh (variant = 'NT')
#   ✓ Keeping: 1.phh (variant = 'NT')
#   ✓ Keeping: 10.phh (variant = 'NT')
#   ✓ Keeping: 100.phh (variant = 'NT')
#   ✓ Keeping: 101.phh (variant = 'NT')
#   ✓ Keeping: 102.phh (variant = 'NT')
#   ✓ Keeping: 103.phh (variant = 'NT')
#   ✓ Keeping: 104.phh (variant = 'NT')
#   ✓ Keeping: 105.phh (variant = 'NT')
#   ✓ Keeping: 106.phh (variant = 'NT')
#   ✓ Keeping: 107.phh (variant = 'NT')
#   ✓ Keeping: 108.phh (variant = 'NT')
#   ✓ Keeping: 109.phh (variant = 'NT')
#   ✓ Keeping: 11.phh (variant = 'NT')
#   ✓ Keeping: 110.phh (variant = 'NT')
#   ✓ Keeping: 111.phh (variant = 'NT')
#   ✓ Keeping: 112.phh (variant = 'NT')
#   ✓ Keeping: 106.phh (variant = 'NT')
#   ✓ Keeping: 107.phh (variant = 'NT')
#   ✓ Keeping: 108.phh (variant = 'NT')
#   ✓ Keeping: 109.phh (variant = 'NT')
#   ✓ Keeping: 11.phh (variant = 'NT')
#   ✓ Keeping: 110.phh (variant = 'NT')
#   ✓ Keeping: 111.phh (variant = 'NT')
#   ✓ Keeping: 112.phh (variant = 'NT')
#   ✓ Keeping: 113.phh (variant = 'NT')
#   ✓ Keeping: 114.phh (variant = 'NT')
#   ✓ Keeping: 115.phh (variant = 'NT')
#   ✓ Keeping: 116.phh (variant = 'NT')
#   ✓ Keeping: 117.phh (variant = 'NT')
#   ✓ Keeping: 118.phh (variant = 'NT')
#   ✓ Keeping: 119.phh (variant = 'NT')
#   ✓ Keeping: 12.phh (variant = 'NT')
#   ✓ Keeping: 120.phh (variant = 'NT')
#   ✓ Keeping: 121.phh (variant = 'NT')
#   ✓ Keeping: 122.phh (variant = 'NT')
#   ✓ Keeping: 113.phh (variant = 'NT')
#   ✓ Keeping: 114.phh (variant = 'NT')
#   ✓ Keeping: 115.phh (variant = 'NT')
#   ✓ Keeping: 116.phh (variant = 'NT')
#   ✓ Keeping: 117.phh (variant = 'NT')
#   ✓ Keeping: 118.phh (variant = 'NT')
#   ✓ Keeping: 119.phh (variant = 'NT')
#   ✓ Keeping: 12.phh (variant = 'NT')
#   ✓ Keeping: 120.phh (variant = 'NT')
#   ✓ Keeping: 121.phh (variant = 'NT')
#   ✓ Keeping: 122.phh (variant = 'NT')
#   ✓ Keeping: 123.phh (variant = 'NT')
#   ✓ Keeping: 124.phh (variant = 'NT')
#   ✓ Keeping: 125.phh (variant = 'NT')
#   ✓ Keeping: 126.phh (variant = 'NT')
#   ✓ Keeping: 127.phh (variant = 'NT')
#   ✓ Keeping: 128.phh (variant = 'NT')
#   ✓ Keeping: 129.phh (variant = 'NT')
#   ✓ Keeping: 13.phh (variant = 'NT')
#   ✓ Keeping: 130.phh (variant = 'NT')
#   ✓ Keeping: 123.phh (variant = 'NT')
#   ✓ Keeping: 124.phh (variant = 'NT')
#   ✓ Keeping: 125.phh (variant = 'NT')
#   ✓ Keeping: 126.phh (variant = 'NT')
#   ✓ Keeping: 127.phh (variant = 'NT')
#   ✓ Keeping: 128.phh (variant = 'NT')
#   ✓ Keeping: 129.phh (variant = 'NT')
#   ✓ Keeping: 13.phh (variant = 'NT')
#   ✓ Keeping: 130.phh (variant = 'NT')
#   ✓ Keeping: 131.phh (variant = 'NT')
#   ✓ Keeping: 132.phh (variant = 'NT')
#   ✓ Keeping: 133.phh (variant = 'NT')
#   ✓ Keeping: 134.phh (variant = 'NT')
#   ✓ Keeping: 135.phh (variant = 'NT')
#   ✓ Keeping: 136.phh (variant = 'NT')
#   ✓ Keeping: 137.phh (variant = 'NT')
#   ✓ Keeping: 138.phh (variant = 'NT')
#   ✓ Keeping: 131.phh (variant = 'NT')
#   ✓ Keeping: 132.phh (variant = 'NT')
#   ✓ Keeping: 133.phh (variant = 'NT')
#   ✓ Keeping: 134.phh (variant = 'NT')
#   ✓ Keeping: 135.phh (variant = 'NT')
#   ✓ Keeping: 136.phh (variant = 'NT')
#   ✓ Keeping: 137.phh (variant = 'NT')
#   ✓ Keeping: 138.phh (variant = 'NT')
#   ✓ Keeping: 139.phh (variant = 'NT')
#   ✓ Keeping: 14.phh (variant = 'NT')
#   ✓ Keeping: 140.phh (variant = 'NT')
#   ✓ Keeping: 141.phh (variant = 'NT')
#   ✓ Keeping: 142.phh (variant = 'NT')
#   ✓ Keeping: 143.phh (variant = 'NT')
#   ✓ Keeping: 144.phh (variant = 'NT')
#   ✓ Keeping: 145.phh (variant = 'NT')
#   ✓ Keeping: 146.phh (variant = 'NT')
#   ✓ Keeping: 147.phh (variant = 'NT')
#   ✓ Keeping: 148.phh (variant = 'NT')
#   ✓ Keeping: 139.phh (variant = 'NT')
#   ✓ Keeping: 14.phh (variant = 'NT')
#   ✓ Keeping: 140.phh (variant = 'NT')
#   ✓ Keeping: 141.phh (variant = 'NT')
#   ✓ Keeping: 142.phh (variant = 'NT')
#   ✓ Keeping: 143.phh (variant = 'NT')
#   ✓ Keeping: 144.phh (variant = 'NT')
#   ✓ Keeping: 145.phh (variant = 'NT')
#   ✓ Keeping: 146.phh (variant = 'NT')
#   ✓ Keeping: 147.phh (variant = 'NT')
#   ✓ Keeping: 148.phh (variant = 'NT')
#   ✓ Keeping: 149.phh (variant = 'NT')
#   ✓ Keeping: 15.phh (variant = 'NT')
#   ✓ Keeping: 150.phh (variant = 'NT')
#   ✓ Keeping: 151.phh (variant = 'NT')
#   ✓ Keeping: 152.phh (variant = 'NT')
#   ✓ Keeping: 153.phh (variant = 'NT')
#   ✓ Keeping: 154.phh (variant = 'NT')
#   ✓ Keeping: 155.phh (variant = 'NT')
#   ✓ Keeping: 156.phh (variant = 'NT')
#   ✓ Keeping: 157.phh (variant = 'NT')
#   ✓ Keeping: 149.phh (variant = 'NT')
#   ✓ Keeping: 15.phh (variant = 'NT')
#   ✓ Keeping: 150.phh (variant = 'NT')
#   ✓ Keeping: 151.phh (variant = 'NT')
#   ✓ Keeping: 152.phh (variant = 'NT')
#   ✓ Keeping: 153.phh (variant = 'NT')
#   ✓ Keeping: 154.phh (variant = 'NT')
#   ✓ Keeping: 155.phh (variant = 'NT')
#   ✓ Keeping: 156.phh (variant = 'NT')
#   ✓ Keeping: 157.phh (variant = 'NT')
#   ✓ Keeping: 158.phh (variant = 'NT')
#   ✓ Keeping: 159.phh (variant = 'NT')
#   ✓ Keeping: 16.phh (variant = 'NT')
#   ✓ Keeping: 160.phh (variant = 'NT')
#   ✓ Keeping: 161.phh (variant = 'NT')
#   ✓ Keeping: 162.phh (variant = 'NT')
#   ✓ Keeping: 163.phh (variant = 'NT')
#   ✓ Keeping: 164.phh (variant = 'NT')
#   ✓ Keeping: 165.phh (variant = 'NT')
#   ✓ Keeping: 166.phh (variant = 'NT')
#   ✓ Keeping: 158.phh (variant = 'NT')
#   ✓ Keeping: 159.phh (variant = 'NT')
#   ✓ Keeping: 16.phh (variant = 'NT')
#   ✓ Keeping: 160.phh (variant = 'NT')
#   ✓ Keeping: 161.phh (variant = 'NT')
#   ✓ Keeping: 162.phh (variant = 'NT')
#   ✓ Keeping: 163.phh (variant = 'NT')
#   ✓ Keeping: 164.phh (variant = 'NT')
#   ✓ Keeping: 165.phh (variant = 'NT')
#   ✓ Keeping: 166.phh (variant = 'NT')
#   ✓ Keeping: 167.phh (variant = 'NT')
#   ✓ Keeping: 168.phh (variant = 'NT')
#   ✓ Keeping: 169.phh (variant = 'NT')
#   ✓ Keeping: 17.phh (variant = 'NT')
#   ✓ Keeping: 170.phh (variant = 'NT')
#   ✓ Keeping: 171.phh (variant = 'NT')
#   ✓ Keeping: 172.phh (variant = 'NT')
#   ✓ Keeping: 173.phh (variant = 'NT')
#   ✓ Keeping: 174.phh (variant = 'NT')
#   ✓ Keeping: 175.phh (variant = 'NT')
#   ✓ Keeping: 167.phh (variant = 'NT')
#   ✓ Keeping: 168.phh (variant = 'NT')
#   ✓ Keeping: 169.phh (variant = 'NT')
#   ✓ Keeping: 17.phh (variant = 'NT')
#   ✓ Keeping: 170.phh (variant = 'NT')
#   ✓ Keeping: 171.phh (variant = 'NT')
#   ✓ Keeping: 172.phh (variant = 'NT')
#   ✓ Keeping: 173.phh (variant = 'NT')
#   ✓ Keeping: 174.phh (variant = 'NT')
#   ✓ Keeping: 175.phh (variant = 'NT')
#   ✓ Keeping: 176.phh (variant = 'NT')
#   ✓ Keeping: 177.phh (variant = 'NT')
#   ✓ Keeping: 178.phh (variant = 'NT')
#   ✓ Keeping: 179.phh (variant = 'NT')
#   ✓ Keeping: 18.phh (variant = 'NT')
#   ✓ Keeping: 180.phh (variant = 'NT')
#   ✓ Keeping: 181.phh (variant = 'NT')
#   ✓ Keeping: 182.phh (variant = 'NT')
#   ✓ Keeping: 183.phh (variant = 'NT')
#   ✓ Keeping: 184.phh (variant = 'NT')
#   ✓ Keeping: 185.phh (variant = 'NT')
#   ✓ Keeping: 186.phh (variant = 'NT')
#   ✓ Keeping: 176.phh (variant = 'NT')
#   ✓ Keeping: 177.phh (variant = 'NT')
#   ✓ Keeping: 178.phh (variant = 'NT')
#   ✓ Keeping: 179.phh (variant = 'NT')
#   ✓ Keeping: 18.phh (variant = 'NT')
#   ✓ Keeping: 180.phh (variant = 'NT')
#   ✓ Keeping: 181.phh (variant = 'NT')
#   ✓ Keeping: 182.phh (variant = 'NT')
#   ✓ Keeping: 183.phh (variant = 'NT')
#   ✓ Keeping: 184.phh (variant = 'NT')
#   ✓ Keeping: 185.phh (variant = 'NT')
#   ✓ Keeping: 186.phh (variant = 'NT')
#   ✓ Keeping: 187.phh (variant = 'NT')
#   ✓ Keeping: 188.phh (variant = 'NT')
#   ✓ Keeping: 189.phh (variant = 'NT')
#   ✓ Keeping: 19.phh (variant = 'NT')
#   ✓ Keeping: 190.phh (variant = 'NT')
#   ✓ Keeping: 191.phh (variant = 'NT')
#   ✓ Keeping: 192.phh (variant = 'NT')
#   ✓ Keeping: 193.phh (variant = 'NT')
#   ✓ Keeping: 2.phh (variant = 'NT')
#   ✓ Keeping: 20.phh (variant = 'NT')
#   ✓ Keeping: 187.phh (variant = 'NT')
#   ✓ Keeping: 188.phh (variant = 'NT')
#   ✓ Keeping: 189.phh (variant = 'NT')
#   ✓ Keeping: 19.phh (variant = 'NT')
#   ✓ Keeping: 190.phh (variant = 'NT')
#   ✓ Keeping: 191.phh (variant = 'NT')
#   ✓ Keeping: 192.phh (variant = 'NT')
#   ✓ Keeping: 193.phh (variant = 'NT')
#   ✓ Keeping: 2.phh (variant = 'NT')
#   ✓ Keeping: 20.phh (variant = 'NT')
#   ✓ Keeping: 21.phh (variant = 'NT')
#   ✓ Keeping: 22.phh (variant = 'NT')
#   ✓ Keeping: 23.phh (variant = 'NT')
#   ✓ Keeping: 24.phh (variant = 'NT')
#   ✓ Keeping: 25.phh (variant = 'NT')
#   ✓ Keeping: 26.phh (variant = 'NT')
#   ✓ Keeping: 27.phh (variant = 'NT')
#   ✓ Keeping: 28.phh (variant = 'NT')
#   ✓ Keeping: 29.phh (variant = 'NT')
#   ✓ Keeping: 3.phh (variant = 'NT')
#   ✓ Keeping: 30.phh (variant = 'NT')
#   ✓ Keeping: 21.phh (variant = 'NT')
#   ✓ Keeping: 22.phh (variant = 'NT')
#   ✓ Keeping: 23.phh (variant = 'NT')
#   ✓ Keeping: 24.phh (variant = 'NT')
#   ✓ Keeping: 25.phh (variant = 'NT')
#   ✓ Keeping: 26.phh (variant = 'NT')
#   ✓ Keeping: 27.phh (variant = 'NT')
#   ✓ Keeping: 28.phh (variant = 'NT')
#   ✓ Keeping: 29.phh (variant = 'NT')
#   ✓ Keeping: 3.phh (variant = 'NT')
#   ✓ Keeping: 30.phh (variant = 'NT')
#   ✓ Keeping: 31.phh (variant = 'NT')
#   ✓ Keeping: 32.phh (variant = 'NT')
#   ✓ Keeping: 33.phh (variant = 'NT')
#   ✓ Keeping: 34.phh (variant = 'NT')
#   ✓ Keeping: 35.phh (variant = 'NT')
#   ✓ Keeping: 36.phh (variant = 'NT')
#   ✓ Keeping: 37.phh (variant = 'NT')
#   ✓ Keeping: 38.phh (variant = 'NT')
#   ✓ Keeping: 39.phh (variant = 'NT')
#   ✓ Keeping: 4.phh (variant = 'NT')
#   ✓ Keeping: 40.phh (variant = 'NT')
#   ✓ Keeping: 41.phh (variant = 'NT')
#   ✓ Keeping: 31.phh (variant = 'NT')
#   ✓ Keeping: 32.phh (variant = 'NT')
#   ✓ Keeping: 33.phh (variant = 'NT')
#   ✓ Keeping: 34.phh (variant = 'NT')
#   ✓ Keeping: 35.phh (variant = 'NT')
#   ✓ Keeping: 36.phh (variant = 'NT')
#   ✓ Keeping: 37.phh (variant = 'NT')
#   ✓ Keeping: 38.phh (variant = 'NT')
#   ✓ Keeping: 39.phh (variant = 'NT')
#   ✓ Keeping: 4.phh (variant = 'NT')
#   ✓ Keeping: 40.phh (variant = 'NT')
#   ✓ Keeping: 41.phh (variant = 'NT')
#   ✓ Keeping: 42.phh (variant = 'NT')
#   ✓ Keeping: 43.phh (variant = 'NT')
#   ✓ Keeping: 44.phh (variant = 'NT')
#   ✓ Keeping: 45.phh (variant = 'NT')
#   ✓ Keeping: 46.phh (variant = 'NT')
#   ✓ Keeping: 47.phh (variant = 'NT')
#   ✓ Keeping: 48.phh (variant = 'NT')
#   ✓ Keeping: 42.phh (variant = 'NT')
#   ✓ Keeping: 43.phh (variant = 'NT')
#   ✓ Keeping: 44.phh (variant = 'NT')
#   ✓ Keeping: 45.phh (variant = 'NT')
#   ✓ Keeping: 46.phh (variant = 'NT')
#   ✓ Keeping: 47.phh (variant = 'NT')
#   ✓ Keeping: 48.phh (variant = 'NT')
#   ✓ Keeping: 49.phh (variant = 'NT')
#   ✓ Keeping: 5.phh (variant = 'NT')
#   ✓ Keeping: 50.phh (variant = 'NT')
#   ✓ Keeping: 51.phh (variant = 'NT')
#   ✓ Keeping: 52.phh (variant = 'NT')
#   ✓ Keeping: 53.phh (variant = 'NT')
#   ✓ Keeping: 54.phh (variant = 'NT')
#   ✓ Keeping: 55.phh (variant = 'NT')
#   ✓ Keeping: 56.phh (variant = 'NT')
#   ✓ Keeping: 57.phh (variant = 'NT')
#   ✓ Keeping: 58.phh (variant = 'NT')
#   ✓ Keeping: 49.phh (variant = 'NT')
#   ✓ Keeping: 5.phh (variant = 'NT')
#   ✓ Keeping: 50.phh (variant = 'NT')
#   ✓ Keeping: 51.phh (variant = 'NT')
#   ✓ Keeping: 52.phh (variant = 'NT')
#   ✓ Keeping: 53.phh (variant = 'NT')
#   ✓ Keeping: 54.phh (variant = 'NT')
#   ✓ Keeping: 55.phh (variant = 'NT')
#   ✓ Keeping: 56.phh (variant = 'NT')
#   ✓ Keeping: 57.phh (variant = 'NT')
#   ✓ Keeping: 58.phh (variant = 'NT')
#   ✓ Keeping: 59.phh (variant = 'NT')
#   ✓ Keeping: 6.phh (variant = 'NT')
#   ✓ Keeping: 60.phh (variant = 'NT')
#   ✓ Keeping: 61.phh (variant = 'NT')
#   ✓ Keeping: 62.phh (variant = 'NT')
#   ✓ Keeping: 63.phh (variant = 'NT')
#   ✓ Keeping: 64.phh (variant = 'NT')
#   ✓ Keeping: 65.phh (variant = 'NT')
#   ✓ Keeping: 66.phh (variant = 'NT')
#   ✓ Keeping: 67.phh (variant = 'NT')
#   ✓ Keeping: 68.phh (variant = 'NT')
#   ✓ Keeping: 69.phh (variant = 'NT')
#   ✓ Keeping: 59.phh (variant = 'NT')
#   ✓ Keeping: 6.phh (variant = 'NT')
#   ✓ Keeping: 60.phh (variant = 'NT')
#   ✓ Keeping: 61.phh (variant = 'NT')
#   ✓ Keeping: 62.phh (variant = 'NT')
#   ✓ Keeping: 63.phh (variant = 'NT')
#   ✓ Keeping: 64.phh (variant = 'NT')
#   ✓ Keeping: 65.phh (variant = 'NT')
#   ✓ Keeping: 66.phh (variant = 'NT')
#   ✓ Keeping: 67.phh (variant = 'NT')
#   ✓ Keeping: 68.phh (variant = 'NT')
#   ✓ Keeping: 69.phh (variant = 'NT')
#   ✓ Keeping: 7.phh (variant = 'NT')
#   ✓ Keeping: 70.phh (variant = 'NT')
#   ✓ Keeping: 71.phh (variant = 'NT')
#   ✓ Keeping: 72.phh (variant = 'NT')
#   ✓ Keeping: 73.phh (variant = 'NT')
#   ✓ Keeping: 74.phh (variant = 'NT')
#   ✓ Keeping: 75.phh (variant = 'NT')
#   ✓ Keeping: 76.phh (variant = 'NT')
#   ✓ Keeping: 77.phh (variant = 'NT')
#   ✓ Keeping: 7.phh (variant = 'NT')
#   ✓ Keeping: 70.phh (variant = 'NT')
#   ✓ Keeping: 71.phh (variant = 'NT')
#   ✓ Keeping: 72.phh (variant = 'NT')
#   ✓ Keeping: 73.phh (variant = 'NT')
#   ✓ Keeping: 74.phh (variant = 'NT')
#   ✓ Keeping: 75.phh (variant = 'NT')
#   ✓ Keeping: 76.phh (variant = 'NT')
#   ✓ Keeping: 77.phh (variant = 'NT')
#   ✓ Keeping: 78.phh (variant = 'NT')
#   ✓ Keeping: 79.phh (variant = 'NT')
#   ✓ Keeping: 8.phh (variant = 'NT')
#   ✓ Keeping: 80.phh (variant = 'NT')
#   ✓ Keeping: 81.phh (variant = 'NT')
#   ✓ Keeping: 82.phh (variant = 'NT')
#   ✓ Keeping: 83.phh (variant = 'NT')
#   ✓ Keeping: 84.phh (variant = 'NT')
#   ✓ Keeping: 85.phh (variant = 'NT')
#   ✓ Keeping: 86.phh (variant = 'NT')
#   ✓ Keeping: 87.phh (variant = 'NT')
#   ✓ Keeping: 78.phh (variant = 'NT')
#   ✓ Keeping: 79.phh (variant = 'NT')
#   ✓ Keeping: 8.phh (variant = 'NT')
#   ✓ Keeping: 80.phh (variant = 'NT')
#   ✓ Keeping: 81.phh (variant = 'NT')
#   ✓ Keeping: 82.phh (variant = 'NT')
#   ✓ Keeping: 83.phh (variant = 'NT')
#   ✓ Keeping: 84.phh (variant = 'NT')
#   ✓ Keeping: 85.phh (variant = 'NT')
#   ✓ Keeping: 86.phh (variant = 'NT')
#   ✓ Keeping: 87.phh (variant = 'NT')
#   ✓ Keeping: 88.phh (variant = 'NT')
#   ✓ Keeping: 89.phh (variant = 'NT')
#   ✓ Keeping: 9.phh (variant = 'NT')
#   ✓ Keeping: 90.phh (variant = 'NT')
#   ✓ Keeping: 91.phh (variant = 'NT')
#   ✓ Keeping: 92.phh (variant = 'NT')
#   ✓ Keeping: 93.phh (variant = 'NT')
#   ✓ Keeping: 94.phh (variant = 'NT')
#   ✓ Keeping: 88.phh (variant = 'NT')
#   ✓ Keeping: 89.phh (variant = 'NT')
#   ✓ Keeping: 9.phh (variant = 'NT')
#   ✓ Keeping: 90.phh (variant = 'NT')
#   ✓ Keeping: 91.phh (variant = 'NT')
#   ✓ Keeping: 92.phh (variant = 'NT')
#   ✓ Keeping: 93.phh (variant = 'NT')
#   ✓ Keeping: 94.phh (variant = 'NT')
#   ✓ Keeping: 95.phh (variant = 'NT')
#   ✓ Keeping: 96.phh (variant = 'NT')
#   ✓ Keeping: 97.phh (variant = 'NT')
#   ✓ Keeping: 98.phh (variant = 'NT')
#   ✓ Keeping: 99.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\wsop\2023\43\5
# Found 11 .phh files
#   ✓ Keeping: 00-02-07.phh (variant = 'NT')
#   ✓ Keeping: 00-08-38.phh (variant = 'NT')
#   ✓ Keeping: 00-15-36.phh (variant = 'NT')
#   ✓ Keeping: 00-18-39.phh (variant = 'NT')
#   ✓ Keeping: 02-51-10.phh (variant = 'NT')
#   ✓ Keeping: 02-53-09.phh (variant = 'NT')
#   ✓ Keeping: 02-54-12.phh (variant = 'NT')
#   ✓ Keeping: 02-56-12.phh (variant = 'NT')
#   ✓ Keeping: 02-57-27.phh (variant = 'NT')
#   ✓ Keeping: 03-00-32.phh (variant = 'NT')
#   ✓ Keeping: 03-02-41.phh (variant = 'NT')
#
# ============================================================
# PROCESSING COMPLETE!
# Folders processed: 93
# Total files processed: 10011
# Files deleted: 0
# Files kept: 10011
# Deletion rate: 0.0%
#   ✓ Keeping: 95.phh (variant = 'NT')
#   ✓ Keeping: 96.phh (variant = 'NT')
#   ✓ Keeping: 97.phh (variant = 'NT')
#   ✓ Keeping: 98.phh (variant = 'NT')
#   ✓ Keeping: 99.phh (variant = 'NT')
#
# Processing folder: phh-dataset\data\wsop\2023\43\5
# Found 11 .phh files
#   ✓ Keeping: 00-02-07.phh (variant = 'NT')
#   ✓ Keeping: 00-08-38.phh (variant = 'NT')
#   ✓ Keeping: 00-15-36.phh (variant = 'NT')
#   ✓ Keeping: 00-18-39.phh (variant = 'NT')
#   ✓ Keeping: 02-51-10.phh (variant = 'NT')
#   ✓ Keeping: 02-53-09.phh (variant = 'NT')
#   ✓ Keeping: 02-54-12.phh (variant = 'NT')
#   ✓ Keeping: 02-56-12.phh (variant = 'NT')
#   ✓ Keeping: 02-57-27.phh (variant = 'NT')
#   ✓ Keeping: 03-00-32.phh (variant = 'NT')
#   ✓ Keeping: 03-02-41.phh (variant = 'NT')
#
# ============================================================
# PROCESSING COMPLETE!
# Folders processed: 93
# Total files processed: 10011
# Files deleted: 0
# Files kept: 10011
# Deletion rate: 0.0%
